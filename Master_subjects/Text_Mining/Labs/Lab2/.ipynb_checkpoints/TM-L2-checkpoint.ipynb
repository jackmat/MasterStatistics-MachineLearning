# %% [markdown]
# # L2: Information Extraction

# %% [markdown]
# In this lab you will implement and evaluate a simple system for information extraction. The task of the system is to read sentences and extract entity pairs of the form *x*&ndash;*y* where *x*&nbsp;is a person, *y*&nbsp;is an organisation, and *x* is the &lsquo;leader&rsquo; of&nbsp;*y*. Consider the following example sentence:
#
# <blockquote>
# Mr. Obama also selected Lisa Jackson to head the Environmental Protection Agency.
# </blockquote>
#
# From this sentence the system should extract the pair
# ```
# ("Lisa Jackson", "Environmental Protection Agency")
# ```
#
# The system will have to solve the following sub-tasks:
# * entity extraction &ndash; identifying mentions of person entities in text
# * relation extraction &ndash; identifying instances of the &lsquo;is-leader-of&rsquo; relation
#
# The data set for the lab consists of 62,010&nbsp;sentences from the [Groningen Meaning Bank](http://gmb.let.rug.nl) (release 2.2.0), an open corpus of English. To analyse the sentences you will use [spaCy](https://spacy.io/).

# %% [markdown]
# ## Getting started

# %% [markdown]
# The first cell imports the Python module required for this lab.

# %%
import tm2

# %% [markdown]
# The data is contained in the following file:

# %%
data_file = "C:/Users/Carles/Desktop/MasterStatistics-MachineLearning/Master_subjects/Text_Mining/Labs/Lab2/gmb.txt"

# %% [markdown]
# The `tm2` module defines a function `read_data` that returns an iterator over the lines in a file. You should use this function to read the data for this lab. Use the optional argument `n` to restrict the iteration to the first few lines of the file. Here is an example:

# %%
data = open(data_file, "r", encoding="utf8")

# %% [markdown]
# The next cell imports spaCy and loads its English language model.

# %%
import spacy

nlp = spacy.load('en', disable=['textcat'])

# %% [markdown]
# ## Entity extraction

# %% [markdown]
# To implement the entity extraction part of your system, you do not need to do much, as you can use the full natural language processing power built into spaCy. The following code extracts the entities from the first 5&nbsp;sentences of the data:

# %%
for i, doc in enumerate(nlp.pipe(data)):
    for ent in doc.ents:
        print("{}\t{}\t{}\t{}".format(ent.text, ent.start, ent.end, ent.label_))
# Out:
# Turkey	13	14	GPE
# 45	16	17	CARDINAL
# at least six	20	23	CARDINAL
# Turkish	0	1	NORP
# Monday	6	7	DATE
# Bilge	11	12	GPE
# about 600 kilometers	12	15	QUANTITY
# Ankara	16	17	GPE
# Mardin	12	13	GPE
# Besir Atalay	2	4	PERSON
# Turkey	0	1	GPE
# NTV	2	3	ORG
# Kurdish	21	22	NORP
# The United Nations	0	3	ORG
# Haiti	4	5	GPE
# Tuesday	4	5	DATE
# U.N.	6	7	ORG
# Kofi Annan	10	12	PERSON
# Haiti	13	14	GPE
# first	26	27	ORDINAL
# Jean-Bertrand Aristide	35	39	PERSON
# February, 2004	40	43	DATE
# recent months	8	10	DATE
# November this year	4	7	DATE
# December	18	19	DATE
# Americans	11	12	NORP
# 46 million	6	8	CARDINAL
# Americans	8	9	NORP
# age this year	16	19	DATE
# VOA	0	1	ORG
# Mil Arcega	2	4	PERSON
# Ethiopia	0	1	GPE
# 18	3	4	CARDINAL
# more than 16 million	16	20	CARDINAL
# the age of five	22	26	DATE
# Tigray	12	13	GPE
# Amhara	14	15	ORG
# Oromia	16	17	ORG
# Wednesday	9	10	DATE
# 100,000	12	13	CARDINAL
# Africa	4	5	LOC
# Indonesia	10	11	GPE
# 2003	13	14	DATE
# Islamic	18	19	NORP
# Nigeria	22	23	GPE
# Bolivian	0	1	NORP
# Evo Morales	4	6	PERSON
# the United States	11	14	GPE
# U.S.	17	18	GPE
# Morales	0	1	PERSON
# Wednesday	4	5	DATE
# South Africa	7	9	GPE
# January 22	13	15	DATE
# Morales	0	1	PERSON
# U.S	12	13	GPE
# Morales	0	1	PERSON
# Venezuelan	0	1	NORP
# Hugo Chavez	2	4	PERSON
# Tuesday	4	5	DATE
# the U.S. Embassy	9	12	ORG
# Bolivia	13	14	GPE
# Morales	20	21	PERSON
# the Associated Press	5	8	ORG
# Genoese	1	2	PERSON
# Monaco	11	12	GPE
# 1215	13	14	DATE
# Grimaldi	3	4	PERSON
# first	5	6	ORDINAL
# 1297	10	11	DATE
# 1331	15	16	DATE
# 1419	27	28	CARDINAL
# late 19th century	6	9	DATE
# France	14	15	GPE
# Monaco	17	18	GPE
# British	1	2	NORP
# one	4	5	CARDINAL
# Iraq	11	12	GPE
# Guardian	1	2	ORG
# Rory Carroll	4	6	PERSON
# 33-year-old	8	11	DATE
# Irishman	11	12	PERSON
# Baghdad	17	18	GPE
# earlier Wednesday	21	23	DATE
# British	3	4	NORP
# British	9	10	NORP
# late Tuesday	18	20	DATE
# Basra	25	26	GPE
# U.S.	2	3	GPE
# one	10	11	CARDINAL
# American	11	12	NORP
# two	15	16	CARDINAL
# late Tuesday	17	19	DATE
# Baghdad	21	22	GPE
# Iskandariyah	24	25	GPE
# Iraqi	6	7	NORP
# Saturday	15	16	DATE
# Lebanon	0	1	GPE
# two	5	6	CARDINAL
# Lebanese	6	7	NORP
# U.N.	11	12	ORG
# Rafik Hariri	20	22	PERSON
# two	7	8	CARDINAL
# Ahmad	10	11	PERSON
# Mahmoud Abdel- Al	12	15	PERSON
# Islamic	24	25	NORP
# Al-Ahbash	28	31	ORG
# U.S.	2	3	GPE
# Syria	9	10	GPE
# U.N.	17	18	ORG
# Hariri	21	22	PERSON
# U.S.	0	1	GPE
# the United Nations	10	13	ORG
# Syrian	0	1	NORP
# U.N.	5	6	ORG
# Syrian	11	12	NORP
# Lebanese	13	14	NORP
# Russia	0	1	GPE
# the Security Council	7	10	ORG
# Syria	17	18	GPE
# The Arab League	0	3	ORG
# Hariri	5	6	PERSON
# Saad	9	10	PERSON
# U.N.	17	18	ORG
# the International Atomic Energy Agency	3	8	ORG
# Mohamed ElBaradei	9	11	PERSON
# the Nobel Peace Prize	30	34	WORK_OF_ART
# Oslo	3	4	GPE
# Norway	5	6	GPE
# ElBaradei	8	9	PERSON
# ElBaradei	11	12	PERSON
# that 15 years	13	16	DATE
# the Cold War	20	23	EVENT
# Europe	26	27	LOC
# Stockhlom	7	8	GPE
# Sweden	9	10	GPE
# Saturday	11	12	DATE
# Literature Prize	0	2	ORG
# Harold Pinter	3	5	PERSON
# U.S	0	1	GPE
# Afghanistan	6	7	GPE
# 24	10	11	CARDINAL
# seven-hour battle in the country's restive south	15	25	TIME
# Wednesday	7	8	DATE
# Sangin	10	11	GPE
# Helmand	13	14	GPE
# Two	0	1	CARDINAL
# Amnesty International	2	4	ORG
# Taleban	5	6	ORG
# Afghanistan	12	13	GPE
# London	1	2	GPE
# Taleban	3	4	ORG
# Amnesty	0	1	ORG
# at least 756	2	5	CARDINAL
# 2006	9	10	DATE
# U.N.	4	5	ORG
# Iran	11	12	GPE
# Arab	13	14	NORP
# Tehran	25	26	GPE
# Iran	30	31	GPE
#
# 	35	36	PERSON
# International Atomic Energy Agency	0	4	ORG
# Mohamed ElBaradei Tuesday	5	8	PERSON
# Arab	9	10	NORP
# Vienna	2	3	GPE
# Elbaradei	4	5	PERSON
# Iran	6	7	GPE
# European	1	2	NORP
# U.S.	5	6	GPE
# Tehran	7	8	GPE
# Iran	16	17	GPE
# IAEA	1	2	ORG
# Tehran	3	4	GPE
# Elbaradei	0	1	PERSON
# Washington	3	4	GPE
# IAEA	9	10	ORG
# Iran	25	26	GPE
# Afghanistan	0	1	GPE
# Tuesday	2	3	DATE
# European Union	6	8	ORG
# United Nations	11	13	ORG
# Humayun Hamidzada	2	4	PERSON
# one	12	13	CARDINAL
# British	13	14	NORP
# Irish	17	18	NORP
# Afghan	22	23	NORP
# two	4	5	CARDINAL
# Helmand	9	10	GPE
# 48 hours	13	15	TIME
# two	1	2	CARDINAL
# Taliban	17	18	ORG
# One	0	1	CARDINAL
# European	1	2	NORP
# U.N.	1	2	ORG
# Aleem Siddique	4	6	PERSON
# U.N.	9	10	ORG
# Afghanistan	12	13	GPE
# Israel	0	1	GPE
# Mordechai Vanunu	5	7	PERSON
# Vanunu	0	1	PERSON
# Israeli	5	6	NORP
# last year	7	9	DATE
# Israel	18	19	GPE
# British	24	25	NORP
# the 1980s	27	29	DATE
# Israeli	8	9	NORP
# November	6	7	DATE
# Israel	16	17	GPE
# up to 200	18	21	CARDINAL
# Israel	0	1	GPE
# Reuters	0	1	ORG
# Vanunu	10	11	PERSON
# Christian	13	14	NORP
# December	28	29	DATE
# midnight	32	33	TIME
# the Palestine Liberation Organization	3	7	ORG
# Israel	14	15	GPE
# PLO	1	2	ORG
# Sunday	7	8	DATE
# hours	9	10	TIME
# Israeli	11	12	NORP
# Ariel Sharon	14	16	PERSON
# Gaza	26	27	GPE
# Sharon	1	2	PERSON
# Palestinian Authority	6	8	ORG
# Mahmoud Abbas	9	11	PERSON
# Israelis	18	19	NORP
# PLO	1	2	ORG
# Israel	9	10	GPE
# Palestinian	14	15	NORP
# Palestinian	0	1	NORP
# Abbas	4	5	PERSON
# Gaza	10	11	GPE
# Wednesday	11	12	DATE
# Jewish	28	29	NORP
# British	0	1	NORP
# Spain	8	9	GPE
# last year's	12	15	DATE
# March 11	15	17	DATE
# Madrid	20	21	GPE
# nearly 200	23	25	CARDINAL
# 39-year-old	5	8	DATE
# Moutaz Almallah	9	11	PERSON
# Spain	10	11	GPE
# Slough	18	19	GPE
# London	22	23	GPE
# Almallah Dabas	1	3	PERSON
# Madrid	12	13	GPE
# London	6	7	GPE
# Bow Street	8	10	FAC
# Monday	14	15	DATE
# Friday	1	2	DATE
# Spanish	3	4	NORP
# Mohannad Almallah Dabas	9	12	PERSON
# Syrian	16	17	NORP
# Madrid	24	25	GPE
# GROOM	1	2	ORG
# U.S.	4	5	GPE
# three to six months	15	19	DATE
# Monday	0	1	DATE
# the Conference Board	8	11	ORG
# 0.3 percent	19	21	PERCENT
# March	22	23	DATE
# late this year	23	26	DATE
# CRAB	1	2	ORG
# Fox	1	2	ORG
# Crab	12	13	NORP
#
# 	46	47	DATE
# The United Nations	0	3	ORG
# Iraq	16	17	GPE
# Saturday	17	18	DATE
# New York	23	25	GPE
# U.N.	0	1	ORG
# Ban Ki-moon	4	8	PERSON
# Iraqi	16	17	NORP
# Nouri al-Maliki	19	23	PERSON
# 20	2	3	CARDINAL
# Iraq	13	14	GPE
# Iran	19	20	GPE
# Kuwait	21	22	GPE
# Syria	23	24	GPE
# the General Assembly	9	12	ORG
# last month	12	14	DATE
# U.N.	17	18	ORG
# Iraq	21	22	GPE
# the International Compact	5	8	ORG
# Iraq	9	10	GPE
# five-year	12	15	DATE
# Ban	1	2	PERSON
# earlier this week	4	7	DATE
# U.N.	11	12	ORG
# Iraq	23	24	GPE
# U.S.	0	1	GPE
# State	3	4	ORG
# Condoleezza Rice	4	6	PERSON
# today	8	9	DATE
# The New York Timessays	0	4	ORG
# two	10	11	CARDINAL
# Iranian	12	13	NORP
# Tehran	19	20	GPE
# the International Atomic Energy Agency	5	10	ORG
# Times	3	4	ORG
# IAEA	9	10	ORG
# Iranian	21	22	NORP
# This week	0	2	DATE
# Iran	3	4	GPE
# U.S.	14	15	GPE
# the U.N. Security Council	21	25	ORG
# Tehran	29	30	GPE
# Iranian	2	3	NORP
# Israeli	0	1	NORP
# three	5	6	CARDINAL
# Palestinians	6	7	NORP
# Israel	9	10	GPE
# Kissufin	16	17	GPE
# Tuesday	19	20	DATE
# Israeli	1	2	NORP
# Israeli	0	1	NORP
# at least five	3	6	CARDINAL
# Palestinian	7	8	NORP
# Gaza	17	18	GPE
# One	0	1	CARDINAL
# Israeli	1	2	NORP
# Palestinian	0	1	NORP
# Karni - the	20	23	FAC
# Israel	30	31	GPE
# the Gaza Strip	32	35	GPE
# Israeli	2	3	NORP
# Khan	13	14	GPE
# Israeli	0	1	NORP
# Gaza	9	10	GPE
# late June	15	17	DATE
# Israeli	28	29	NORP
# The European Parliament	0	3	ORG
# the European Union	8	11	ORG
# EU	18	19	ORG
# nearly three weeks	22	25	DATE
# early Thursday	5	7	DATE
# Jose Manuel Barroso	6	9	PERSON
# Monday	13	14	DATE
# Barroso	5	6	PERSON
# Barroso	10	11	PERSON
# late last month	9	12	DATE
# Barroso	15	16	PERSON
# first	18	19	ORDINAL
# French	3	4	NORP
# Mustard	5	6	PERSON
# French	3	4	NORP
# France	19	20	GPE
# France	20	21	GPE
# Rochester, NY	7	10	GPE
# Cuban	0	1	NORP
# Fidel Castro	2	4	PERSON
# Cubans	27	28	NORP
# the past two years	29	33	DATE
# Tuesday	3	4	DATE
# Castro	6	7	PERSON
# Cuba	0	1	GPE
# 2004	8	9	DATE
# Cubans	3	4	NORP
# the hottest months	11	14	DATE
# summer	15	16	DATE
# Palestinian	2	3	NORP
# Gaza Strip	10	12	GPE
# Palestinian	0	1	NORP
# two	7	8	CARDINAL
# Friday - the	13	16	DATE
# Khan Younis	19	21	PERSON
# Rafah	22	23	ORG
# Israeli	9	10	NORP
# Jewish	12	13	NORP
# Palestinian	3	4	NORP
# Israeli	7	8	NORP
# Moshe Yaalon	11	13	PERSON
# the Gaza Strip	23	26	GPE
# Palestinian	27	28	NORP
# Israeli	0	1	NORP
# Ariel Sharon	3	5	PERSON
# Thursday	6	7	DATE
# the Middle East	17	20	LOC
# Palestinian	29	30	NORP
# Sharon	1	2	PERSON
# Israeli	6	7	NORP
# Israel	9	10	GPE
# Palestinian	19	20	NORP
# Mahmoud Abbas	21	23	PERSON
# John Mayer	2	4	PERSON
# 10th	12	13	ORDINAL
# VH1	3	4	ORG
# U.S.	11	12	GPE
# $34 million	20	23	MONEY
# September 20	2	4	DATE
# New York City's	5	9	GPE
# Lincoln Center	9	11	ORG
# 50	17	18	CARDINAL
# the past decade	26	29	DATE
# Iranian	0	1	NORP
# Mahmoud Ahmadinejad	2	4	PERSON
# U.S.	10	11	NORP
# George Bush	12	14	PERSON
# the United States	17	20	GPE
# Iran	26	27	GPE
# Ahmadinejad	1	2	PERSON
# Wednesday	3	4	DATE
# Bush	6	7	PERSON
# Iranian	1	2	NORP
# Bush	9	10	PERSON
# Iran	14	15	GPE
# U.S.	18	19	GPE
# one	28	29	CARDINAL
# Ahmadinejad	1	2	PERSON
# Iranian	10	11	NORP
# Shahr	13	14	GPE
# Tuesday	1	2	DATE
# Bush	4	5	PERSON
# European Union	6	8	ORG
# Slovenia	11	12	GPE
# Iran	19	20	GPE
#
# 	27	28	PERSON
# The United States	0	3	GPE
# five	4	5	CARDINAL
# Iran	11	12	GPE
# EU	0	1	ORG
# Javier Solana	4	6	PERSON
# Tehran	8	9	GPE
# later this week	9	12	DATE
# U.S.	1	2	GPE
# five	4	5	CARDINAL
# American	5	6	NORP
# Iraq	9	10	GPE
# Thursday	10	11	DATE
# four	13	14	CARDINAL
# Baghdad	7	8	GPE
# two	10	11	CARDINAL
# Baghdad	14	15	GPE
# Salahaddin province	16	18	GPE
#
# 	19	20	GPE
# Friday	7	8	DATE
# one	9	10	CARDINAL
# Baghdad	14	15	GPE
# Zafaraniyah	17	18	GPE
# Kirkuk	5	6	GPE
# two	11	12	CARDINAL
# British	3	4	NORP
# British	14	15	NORP
# Basra	24	25	GPE
# Reutersnews	1	2	ORG
# 10	4	5	CARDINAL
# earlier this week	7	10	DATE
# Coach	0	1	PERSON
# 4	4	5	CARDINAL
# Portugal	0	1	GPE
# Asia	23	24	LOC
# the Portuguese Football Federation	3	7	ORG
# Portugal	8	9	GPE
# Asian	22	23	NORP
# last weekend's	26	29	DATE
# the first two weeks of January	6	12	DATE
# Lisbon	13	14	GPE
# 65,000	15	16	CARDINAL
# Stadium of Light	17	20	ORG
# as many as 150,000	28	32	CARDINAL
# Indian	1	2	NORP
# Pakistan	8	9	GPE
# Kashmir	21	22	GPE
# China	27	28	GPE
# India	0	1	GPE
# Friday	5	6	DATE
# Himalayan	15	16	NORP
# Pakistan	24	25	GPE
# Kashmir	0	1	ORG
# India	4	5	GPE
# Pakistan	6	7	GPE
# Last month	0	2	DATE
# Pakistan	3	4	GPE
# China	5	6	GPE
# Bunji	16	17	ORG
# Pakistan	27	28	GPE
# India	6	7	GPE
# Pakistan	8	9	GPE
# China	13	14	GPE
# Friday	0	1	DATE
# Pakistan	2	3	GPE
# the Indian High Commission	7	11	ORG
# Islamabad	12	13	GPE
# India	16	17	GPE
# Burma	3	4	GPE
# Independence Day	9	11	FAC
# this week	12	14	DATE
# 73-year-old	2	5	DATE
# Than Shwe	6	8	PERSON
# Thursday	11	12	DATE
# evening	12	13	TIME
# Singapore	22	23	GPE
# first	3	4	ORDINAL
# Than Shwe	6	8	PERSON
# 1992	11	12	DATE
# annual	18	19	DATE
# second	6	7	ORDINAL
# General Maung Aye	12	15	ORG
# this year	19	21	DATE
# Than Shwe's	6	9	PERSON
# Singapore	12	13	GPE
# The U.S. Surgeon General	0	4	ORG
# America	5	6	GPE
# Tuesday	14	15	DATE
# 2005	1	2	DATE
# Disease Control	7	9	ORG
# some 3,000	16	18	CARDINAL
# each year	19	21	DATE
# 46,000	26	27	CARDINAL
# Secondhand	0	1	NORP
# 430	6	7	CARDINAL
# annually	9	10	DATE
# the United States	11	14	GPE
# U.S.	0	1	GPE
# Afghanistan	4	5	GPE
# three	10	11	CARDINAL
# Taleban	11	12	ORG
# Paktika province	24	26	GPE
# Pakistani	29	30	NORP
# Afghan	4	5	NORP
# two	7	8	CARDINAL
# late Tuesday	18	20	DATE
# Taleban	7	8	ORG
# Raz Mohammed	9	11	PERSON
# Wednesday, five	0	3	DATE
# U.S.	11	12	GPE
# Khost province	15	17	GPE
# U.S	0	1	GPE
# Afghanistan	6	7	GPE
# Taleban	9	10	ORG
# Islamic	25	26	NORP
# 2001	30	31	DATE
# Asian	0	1	NORP
# Monday	4	5	DATE
# the United States	11	14	GPE
# Asian	19	20	NORP
# China	0	1	GPE
# Shanghai Composite Index	2	5	ORG
# more than 7	6	9	CARDINAL
# Tokyo	14	15	GPE
# Sensex	16	17	GPE
# Mumbai	18	19	GPE
# almost 4 percent	22	25	PERCENT
# Hong Kong's	0	3	GPE
# Hang Seng	3	5	PERSON
# more than 5 percent	7	11	PERCENT
# European	2	3	NORP
# London	5	6	GPE
# Paris	7	8	GPE
# Frankfurt	9	10	GPE
# midday	14	15	TIME
# Asia	21	22	LOC
# about 2 percent	24	27	PERCENT
# last week's	7	10	DATE
# Bush	16	17	PERSON
# U.S.	23	24	GPE
# The U.S. Federal Reserve	0	4	ORG
# this week	5	7	DATE
# Indian	0	1	NORP
# one	3	4	CARDINAL
# at least 26	8	11	CARDINAL
# Indian	17	18	NORP
# Kashmir	20	21	GPE
# Wednesday	21	22	DATE
# Rajouri	16	17	GPE
# about 100 miles	19	22	QUANTITY
# Jammu	24	25	GPE
# Kashmir	28	29	LOC
# Kashmir	10	11	LOC
# Indian	5	6	NORP
# Kashmir	8	9	LOC
# 1989	10	11	DATE
# India	11	12	GPE
# Pakistan	13	14	GPE
# two	16	17	CARDINAL
# more than a year ago	12	17	DATE
# 8:20 am	4	6	TIME
# Rugova	8	9	PERSON
# European Union	17	19	ORG
# Javier Solana	22	24	PERSON
# Rugova	1	2	PERSON
# Kosovo	22	23	GPE
# Venezuelan	0	1	NORP
# Hugo Chavez	2	4	PERSON
# Venezuelans	14	15	NORP
# Chavez	1	2	PERSON
# Tuesday	5	6	DATE
# just days	3	5	DATE
# Chavez	7	8	PERSON
# Venezuela	10	11	GPE
# two	12	13	CARDINAL
# Chavez	25	26	PERSON
# Venezuelans	3	4	NORP
# two	6	7	CARDINAL
# Chavez	1	2	PERSON
# U.S.	14	15	GPE
# Tim Nardiello	0	2	PERSON
# U.S.	7	8	GPE
# two	24	25	CARDINAL
# U.S.	1	2	GPE
# Skeleton Federation	4	6	ORG
# Nardiello	8	9	ORG
# Monday	15	16	DATE
# season	9	10	DATE
# World Cup	13	15	PERSON
# Altenberg	16	17	GPE
# Germany	18	19	GPE
# Thursday	21	22	DATE
# Friday	23	24	DATE
# the U.S. Olympic Committee	4	8	ORG
# Nardiello	11	12	ORG
# four	15	16	CARDINAL
# American	16	17	NORP
# the Turin Olympics	19	22	FAC
# February 10	26	28	DATE
# Monday	1	2	DATE
# U.S.	5	6	GPE
# Zach Lund	13	15	PERSON
# the U.S. Anti-Doping Agency	23	29	ORG
# this season	34	36	DATE
# Sweden	0	1	GPE
# The Swedish Security Service	0	4	ORG
# Friday	5	6	DATE
# Sweden	9	10	GPE
# Sweden	0	1	GPE
# earlier this week	7	10	DATE
# Pakistan	18	19	GPE
# several European capitals	21	24	NORP
# U.S.	0	1	GPE
# European	2	3	NORP
# European	26	27	NORP
# Swedish	0	1	NORP
# Sweden	9	10	GPE
# European	15	16	NORP
# U.S.	1	2	GPE
# NASA	4	5	ORG
# PhoenixMars	7	8	ORG
# Tuesday	4	5	DATE
# NASA	5	6	ORG
# Phoenix	0	1	GPE
# Martian	7	8	NORP
# NASA	0	1	ORG
# Sunday	9	10	DATE
# Mars	19	20	GPE
# about one day	27	30	DATE
# Canadian	3	4	NORP
# 30	18	19	DATE
# 80	21	22	CARDINAL
# Celsius	23	24	DATE
# 32	27	28	CARDINAL
# Brazilian	0	1	NORP
# Rio de Janeiro	16	19	ORG
# hours	25	26	TIME
# two	1	2	CARDINAL
# Providencia	14	15	GPE
# Friday	16	17	DATE
# force one week ago	6	10	DATE
# 11	16	17	CARDINAL
# About 1,500	0	2	CARDINAL
# one	2	3	CARDINAL
# hundreds	15	16	CARDINAL
# each year	18	20	DATE
# Indonesia	0	1	GPE
# more than 7,000	3	6	CARDINAL
# last month's	12	15	DATE
# nearly 174,000	29	31	CARDINAL
# Welfare	0	1	ORG
# Alwi Shihab	2	4	PERSON
# Saturday	5	6	DATE
# an estimated 100,000	7	10	CARDINAL
#
# 	18	19	GPE
# Shihab	1	2	PERSON
# Sri Lanka's	2	5	GPE
# Tamil	5	6	NORP
# Norwegian	4	5	NORP
# Jan Petersen	7	9	PERSON
# Kilinochchi Saturday	18	20	PERSON
# Petersen	1	2	PERSON
# Sri Lanka	4	6	GPE
# Palestinian	0	1	NORP
# Israel	4	5	GPE
# the West Bank	9	12	GPE
# Nablus	14	15	GPE
# two days	16	18	DATE
# Israeli	4	5	NORP
# Nablus	8	9	GPE
# late Monday	9	11	DATE
# Israeli	3	4	NORP
# Israeli	0	1	NORP
# Palestinian	6	7	NORP
# early Sunday	8	10	DATE
# dozens	12	13	CARDINAL
# about 50,000	6	8	CARDINAL
# Palestinians	8	9	NORP
# Palestinians	0	1	NORP
# Israeli	2	3	NORP
# Monday	4	5	DATE
# one	6	7	CARDINAL
# Palestinian	7	8	NORP
# Israeli	1	2	NORP
# at least three	7	10	CARDINAL
# Palestinian	0	1	NORP
# Israel	0	1	GPE
# Nablus	4	5	GPE
# Israeli	18	19	NORP
# one	1	2	CARDINAL
# Yugoslav	7	8	NORP
# Croatia	10	11	GPE
# the 1991-95 war	16	21	DATE
# Central	34	35	GPE
# Eastern Europe	36	38	LOC
# the Berlin Wall	43	46	FAC
# Between 2000 and 2007	0	4	DATE
# Croatia	7	8	GPE
# between 4% and 6% led by	22	28	PERCENT
# the same period	2	5	DATE
# EU	1	2	ORG
# Croatia	11	12	GPE
# Croatia	0	1	GPE
# Taiwan	3	4	GPE
# Chen Shui-bian's	1	6	PERSON
# Democratic Progressive Party	6	9	ORG
# the Taiwan Solidarity Union	13	17	ORG
# about three	19	21	CARDINAL
# Nationalist	26	27	NORP
# about a third	30	33	CARDINAL
# Chen	1	2	PERSON
# Taiwan	14	15	GPE
# 225-seat	16	17	CARDINAL
# the Nationalist Party	4	7	ORG
# Beijing	12	13	GPE
# 51 percent	16	18	PERCENT
# 386	3	4	CARDINAL
# 176	7	8	CARDINAL
# 49	2	3	CARDINAL
# 9:00 p.m.	6	8	TIME
# The United States	0	3	GPE
# six	8	9	CARDINAL
# North Korea's	13	16	GPE
# Reuters	4	5	ORG
# AFP	6	7	ORG
# State	10	11	ORG
# Condoleezza Rice	11	13	PERSON
# the United States	14	17	GPE
# Pyongyang	20	21	GPE
# North Korea	0	2	GPE
# fourth	10	11	ORDINAL
# the United States	16	19	GPE
# Rice	30	31	PERSON
# U.S.	4	5	GPE
# Seoul	8	9	GPE
# South Korean	12	14	NORP
# Tokyo	18	19	GPE
# Beijing	20	21	GPE
# Michael Green	0	2	PERSON
# Asian	5	6	NORP
# the U.S. National Security Council	8	13	ORG
# Bush	16	17	PERSON
# Pyongyang	23	24	GPE
# Burma	0	1	GPE
# Saturday	5	6	DATE
# 13	30	31	CARDINAL
# New Light of Myanmar	4	8	ORG
# February 20	15	17	DATE
# Tachileik	22	23	GPE
# Thailand	26	27	GPE
# Mekong	11	12	GPE
# Tachileik	14	15	GPE
# Eight	0	1	CARDINAL
# two	7	8	CARDINAL
# three	12	13	CARDINAL
# Two	0	1	CARDINAL
# 15	12	13	CARDINAL
# several days later	14	17	DATE
# Mekong	22	23	GPE
# Hamas	0	1	ORG
# Islamic	6	7	NORP
# Israel	14	15	GPE
# the end of this year	18	23	DATE
# Palestinian	5	6	NORP
# Syrian	10	11	NORP
# Friday	12	13	DATE
# Khaled Mashaal	14	16	PERSON
# Hamas	17	18	ORG
# Palestinian	26	27	NORP
# Mashaal	3	4	PERSON
# al-Jazeera	5	8	ORG
# Israel	2	3	GPE
# Israel	0	1	GPE
# The Associated Press	0	3	ORG
# the Palestinian Authority	4	7	ORG
# Mashaal	9	10	PERSON
# Luxembourg	2	3	GPE
# European Union Constitution	7	10	ORG
# Sunday	13	14	DATE
# France	20	21	GPE
# Netherlands	23	24	GPE
# last month	24	26	DATE
# about 57 to 43	17	21	CARDINAL
# Jean-Claude Juncker	2	6	PERSON
# first	3	4	ORDINAL
# French	9	10	NORP
# Dutch	11	12	NORP
# last month	15	17	DATE
# Britain	11	12	GPE
# Denmark	13	14	GPE
# Portugal	15	16	GPE
# Sweden	17	18	GPE
# Finland	19	20	GPE
# 25	1	2	CARDINAL
# Israeli	0	1	NORP
# Palestinian	4	5	NORP
# two	10	11	CARDINAL
# Israeli	11	12	NORP
# Israeli	16	17	NORP
# Beersheba	19	20	GPE
# morning	16	17	TIME
# Palestinian	0	1	NORP
# Mahmoud Abbas	2	4	PERSON
# first	9	10	ORDINAL
# Israel	13	14	GPE
# Jewish	16	17	NORP
# the Gaza Strip	19	22	GPE
# earlier this month	22	25	DATE
# Israeli	3	4	NORP
# Egyptian	10	11	NORP
# Egypt	13	14	GPE
# Gaza	17	18	GPE
# Cairo	4	5	GPE
# Egypt	6	7	GPE
# 750	10	11	CARDINAL
# Egyptian	15	16	NORP
# Israeli	19	20	NORP
# Israel	0	1	GPE
# Gaza	7	8	GPE
# the end of September	14	18	DATE
# Pakistan	2	3	GPE
# Taleban	7	8	ORG
# U.S	19	20	GPE
# Afghanistan	26	27	GPE
# Saturday	3	4	DATE
# Rahim Jan	12	14	PERSON
# North Waziristan	20	22	GPE
# 70 years old	2	5	DATE
# North Waziristan	2	4	GPE
# Taleban	10	11	ORG
# Pakistani	0	1	NORP
# Pervez Musharraf	2	4	PERSON
# Tuesday	8	9	DATE
# Pakistan	4	5	GPE
# Qaida	23	24	GPE
# Pakistan	31	32	GPE
# Afghanistan	34	35	GPE
# Italian	0	1	NORP
# Montedison S.p	3	5	ORG
# Montedison Acquisition N.V.	10	13	ORG
# 37-a	19	20	MONEY
# Erbamont N.V.	31	33	ORG
# Netherlands	41	42	GPE
# today	5	6	DATE
# The Wall Street Journal	9	13	ORG
# the end of November	19	23	DATE
# Montedison	0	1	ORG
# about 72% of	3	6	PERCENT
# Erbamont	6	7	ORG
# Burkina Faso	0	2	GPE
# Upper Volta	4	6	PERSON
# France	10	11	GPE
# 1960	12	13	DATE
# the 1970s and 1980s	4	8	DATE
# the early 1990s	14	17	DATE
# Blaise COMPAORE	2	4	PERSON
# 1987	9	10	DATE
# Burkina Faso's	0	3	GPE
# Cote d'Ivoire	3	5	PERSON
# Ghana	7	8	GPE
# several hundred thousand	13	16	CARDINAL
# Burkinabe	17	18	ORG
# China	0	1	GPE
# May 12th quake	25	28	DATE
# China	0	1	GPE
# one	3	4	CARDINAL
# May 12th	6	8	DATE
# more than 6,000	13	16	CARDINAL
# Chinese	8	9	NORP
# New York	1	3	GPE
# Colombian	7	8	NORP
# Alberto Orlandez Gamboa	10	13	PERSON
# 40 years	14	16	DATE
# the United States	29	32	GPE
# Thursday	4	5	DATE
# 49-year-old	8	11	DATE
# Orlandez Gamboa	11	13	PERSON
# Colombia	20	21	GPE
# 10	23	24	CARDINAL
# the United States	8	11	GPE
# several years ago	11	14	DATE
# Orlandez Gamboa	2	4	PERSON
# about a dozen	8	11	CARDINAL
# Barranquilla	16	17	GPE
# Colombia	18	19	GPE
# the United States	26	29	GPE
# Colombia	0	1	GPE
# the United States	9	12	GPE
# Morocco	0	1	GPE
# two-thirds	4	7	CARDINAL
# Western Sahara	8	10	ORG
# Spanish Sahara	12	14	PERSON
# 1976	16	17	DATE
# 1979	25	26	DATE
# Mauritania	28	29	GPE
# the Polisario Front	4	7	ORG
# Morocco	8	9	GPE
# 1991	14	15	DATE
# UN	15	16	ORG
# UN	23	24	ORG
# UN	1	2	ORG
# 2007	3	4	DATE
# Morocco	14	15	GPE
# the Polisario Front	16	19	ORG
# Sahara	25	26	GPE
# Morocco	0	1	GPE
# Moroccan	20	21	NORP
# Algeria	4	5	GPE
# United Nations	0	2	ORG
# Haiti	5	6	GPE
# Jean-Bertrand Aristide	13	17	PERSON
# Haiti	0	1	GPE
# Tabarre	16	17	GPE
# Thursday	3	4	DATE
# U.N.	4	5	ORG
# three-week	9	12	DATE
# Aristide	16	17	PERSON
# February - moved	18	21	DATE
# Wednesday	25	26	DATE
# Aristide	1	2	PERSON
# South Africa	6	8	GPE
# seventh	1	2	ORDINAL
# Sudan	7	8	GPE
# Darfur	10	11	GPE
# African	1	2	NORP
# Nigerian	12	13	NORP
# Abuja,	15	17	GPE
# Monday	17	18	DATE
# African Union	0	2	ORG
# several days	12	14	DATE
# Nureddin Mezni	2	4	PERSON
# the French News Agency	5	9	ORG
# AFP	10	11	ORG
# October	7	8	DATE
# Darfur	15	16	GPE
# Darfur	19	20	PERSON
# Saturday	0	1	DATE
# U.S.	4	5	GPE
# State	10	11	ORG
# Jendayi Frazer	15	17	PERSON
# Sudan Liberation Army	25	28	ORG
# U.S.	1	2	GPE
# New Delhi	4	6	GPE
# India	21	22	GPE
# Iran	25	26	GPE
# the United Nations Security Council	27	32	ORG
# Thursday	3	4	DATE
# David Mulford	6	8	PERSON
# Washington	1	2	GPE
# the State Department	3	6	ORG
# Mulford	9	10	PERSON
# Thursday	1	2	DATE
# India	3	4	GPE
# Shyam Saran	7	9	PERSON
# Mulford	11	12	PERSON
# two	30	31	CARDINAL
# U.S.	6	7	GPE
# India	13	14	GPE
# New Delhi	22	24	GPE
# India	3	4	GPE
# POLITICAL	1	2	NORP
# one	6	7	CARDINAL
# Shadow	14	15	GPE
# Shadow	11	12	ORG
# BP	1	2	ORG
# Robert Dudley	3	5	PERSON
# Russia	10	11	GPE
# next week	11	13	DATE
# first	15	16	ORDINAL
# 2008	22	23	DATE
# BP	28	29	ORG
# Russian	31	32	NORP
# TNK-BP	33	36	ORG
# Dudley	0	1	PERSON
# TNK-BP	7	10	ORG
# Moscow	14	15	GPE
# BP	17	18	ORG
# Tony Hayward	19	21	PERSON
# Russian	6	7	NORP
# Venezuelan	14	15	NORP
# BP	17	18	ORG
# TNK-BP	19	22	ORG
# the Gulf of Mexico oil spill	29	35	EVENT
# Dudley	0	1	PERSON
# Russia	5	6	GPE
# 2008	7	8	DATE
# TNK- BP	14	16	GPE
# Tony Hayward October	3	6	PERSON
# Cuba	0	1	GPE
# more than 500,000	12	15	CARDINAL
# March	19	20	DATE
# The Cuban Workers Confederation	0	4	ORG
# Cuba	13	14	GPE
# 95 percent	5	7	PERCENT
# Several weeks ago	0	3	DATE
# Cuban	4	5	NORP
# Raul Castro	6	8	PERSON
# Cubans	24	25	NORP
# Cubans	9	10	NORP
# Bush	1	2	PERSON
# Supreme Court	8	10	ORG
# Bush	1	2	PERSON
# U.S.	4	5	GPE
# Saturday	6	7	DATE
# Samuel Alito	8	10	PERSON
# Supreme Court	25	27	ORG
# more than	29	31	PERCENT
# 70 years	31	33	DATE
# Judge Alito	3	5	PERSON
# American	9	10	NORP
# Friday	1	2	DATE
# Senate	11	12	ORG
# January 9	19	21	DATE
# Sandra Day O'Connor	30	33	PERSON
# Bush	1	2	PERSON
# Alito	4	5	PERSON
# October 31,	5	8	DATE
# four days	8	10	DATE
# first	12	13	ORDINAL
# Harriet Miers	14	16	PERSON
# Iraqi	0	1	NORP
# 50	3	4	CARDINAL
# Sunday	12	13	DATE
# two	21	22	CARDINAL
# Najaf	26	27	GPE
# Karbala	28	29	GPE
# 66 - at least 52	12	17	CARDINAL
# Najaf	20	21	GPE
# 14	22	23	CARDINAL
# Karbala	24	25	GPE
# More than 140	0	3	CARDINAL
# Muslim	1	2	NORP
# Iraq	20	21	GPE
# first	22	23	ORDINAL
# Saddam	25	26	PERSON
# six weeks	33	35	DATE
# January 30	37	39	DATE
# Shi'ite	0	1	NORP
# Colombian	1	2	NORP
# more than 100	4	7	CARDINAL
# Ecuadorean	7	8	NORP
# the Pacific Ocean	22	25	LOC
# Wednesday	2	3	DATE
# the United States	10	13	GPE
# last Friday	22	24	DATE
# Colombia	25	26	GPE
# Seven	0	1	CARDINAL
# two	3	4	CARDINAL
# Ecuadorean	4	5	NORP
# 15	10	11	CARDINAL
# as many as 120	14	18	CARDINAL
# Colombian	1	2	NORP
# Ecuador	0	1	GPE
# Ecuadorean	10	11	NORP
# Manta	13	14	GPE
# Palestinian	0	1	NORP
# Mahmoud Abbas	4	6	PERSON
# the Gaza Strip Saturday	9	13	GPE
# first	15	16	ORDINAL
# Fatah	24	25	ORG
# Hamas	30	31	ORG
# Abbas	1	2	PERSON
# Fatah	3	4	ORG
# Ismail Haniyeh	7	9	PERSON
# Hamas	10	11	ORG
# Jordan	18	19	GPE
# Abdullah	21	22	PERSON
# Fatah	2	3	ORG
# Hamas	4	5	ORG
# months	9	10	DATE
# Last month	0	2	DATE
# Gaza	12	13	GPE
# the West Bank	14	17	GPE
# At least 17	0	3	CARDINAL
# last week	4	6	DATE
# The United Nations World Food	0	5	ORG
# Somalians	19	20	NORP
# WFP	1	2	ORG
# Miltzow	5	6	PERSON
# Wednesday	9	10	DATE
# afternoon	10	11	TIME
# Merka	15	16	GPE
# Miltzow	1	2	PERSON
# Monday	1	2	DATE
# Torgelow	5	6	PERSON
# Somalia	13	14	GPE
# Torgelow	1	2	ORG
# Semlow	12	13	PRODUCT
# Semlow	1	2	ORG
# June	5	6	DATE
# Kenya	10	11	GPE
# Somalia	12	13	GPE
# Japan	20	21	GPE
# Germany	22	23	GPE
# The African Union's	0	4	ORG
# African	12	13	NORP
# Togo	18	19	GPE
# Faure Gnassingbe	26	28	PERSON
# Friday	2	3	DATE
# West African	7	9	NORP
# ECOWAS	10	11	ORG
# AU	15	16	GPE
# 53	17	18	CARDINAL
# ECOWAS	0	1	ORG
# Togolese	12	13	NORP
# Friday	1	2	DATE
# Togo	7	8	GPE
# George Dahoun Gignor	12	15	PERSON
# VOA	17	18	ORG
# Gnassingbe	20	21	PERSON
#
# 	33	34	PERSON
# Friday	5	6	DATE
# Gnassingbe	8	9	PERSON
# 60 days	17	19	DATE
# Gnassingbe	1	2	PERSON
# earlier this month	3	6	DATE
# Gnassingbe Eyadema	13	15	PERSON
# US	0	1	GPE
# Donald Rumsfeld	4	6	PERSON
# Russian	10	11	NORP
# Sergei Ivanov	13	15	PERSON
# Washington Tuesday	6	8	GPE
# Rumsfeld	10	11	PERSON
# Iraq	17	18	GPE
# later this month	20	23	DATE
# Sunnis	8	9	NORP
# January 30	15	17	DATE
# Rumsfeld	1	2	PERSON
# the United States	7	10	GPE
# Syria	16	17	GPE
# two	1	2	CARDINAL
# Ivanov	1	2	PERSON
# today	5	6	DATE
# the White House	7	10	FAC
# Bush	12	13	PERSON
# one	3	4	CARDINAL
# two	5	6	CARDINAL
# Gaza City	10	12	GPE
# Monday	12	13	DATE
# New Zealand	5	7	GPE
# Wednesday	8	9	DATE
# Palestinians	21	22	NORP
# American	6	7	NORP
# Palestinian	0	1	NORP
# two	7	8	CARDINAL
# U.S.	13	14	GPE
# Fox News	16	18	ORG
# Palestinian	5	6	NORP
# Mahmoud Abbas	7	9	PERSON
# Fatah	11	12	ORG
# Hamas	17	18	ORG
# Hamas	4	5	ORG
# Israel	10	11	GPE
# Israeli	8	9	NORP
# Wednesday	12	13	DATE
# Gaza	18	19	GPE
# two	21	22	CARDINAL
# Israeli	1	2	NORP
# Niger	0	1	GPE
# Mamadou Tandja	2	4	PERSON
# Seyni Oumarou's	8	11	PERSON
# last month	32	34	DATE
# Oumarou	2	3	PERSON
# this week	5	7	DATE
# Niger	8	9	GPE
# Hama Amadou's	15	18	PERSON
# May 31	20	22	DATE
# Amadou	1	2	PERSON
# Niger	13	14	GPE
# Two	0	1	CARDINAL
# hundreds of thousands	12	15	CARDINAL
# Saturday	10	11	DATE
# Aichatou Mindaoudou	15	17	PERSON
# Interior	18	19	ORG
# Albade Abouba	20	22	PERSON
# Ali Mahamane	27	29	PERSON
# Lamine Zeine	29	31	PERSON
# Tibet	0	1	GPE
# the Dalai Lama	5	8	ORG
# Burma	18	19	GPE
# Buddhist	22	23	NORP
# VOA	4	5	ORG
# Washington	6	7	GPE
# Tuesday	7	8	DATE
# the Dalai Lama	9	12	ORG
# Buddhist	20	21	NORP
# Burma	23	24	GPE
# Lama	2	3	PERSON
# Buddhist	5	6	NORP
# Burma	8	9	GPE
# Lama	2	3	PERSON
# VOA	5	6	ORG
# Bush	10	11	PERSON
# Washington	12	13	GPE
# Tuesday	14	15	DATE
# Burmese	1	2	NORP
# Burma	12	13	GPE
# last month	13	15	DATE
# at least 10	16	19	CARDINAL
# Somalia	2	3	GPE
# Islamist	7	8	NORP
# Ethiopian	10	11	NORP
# at least five	14	17	CARDINAL
# Islamic	5	6	NORP
# Ethiopian	9	10	NORP
# Mogadishu	13	14	GPE
# Ethiopian	0	1	NORP
# Somalia	3	4	GPE
# two years ago	4	7	DATE
# Islamist	14	15	NORP
# Somalia	0	1	GPE
# the fall of dictator	8	12	DATE
# Mohamed Siad Barre	12	15	PERSON
# 1991	16	17	DATE
# United Nations	0	2	ORG
# Congolese	10	11	NORP
# Democratic Republic of Congo	17	21	GPE
# U.N.	1	2	ORG
# Sunday	4	5	DATE
# Kanyabayonga	12	13	GPE
# Tens of thousands	0	3	CARDINAL
# more than a week	12	16	CARDINAL
# thousands	9	10	CARDINAL
# Congo	17	18	GPE
# Kinshasa	0	1	GPE
# Rwanda	6	7	GPE
# Rwandan Hutu	14	16	PERSON
# Congo	19	20	GPE
# Rwanda	0	1	GPE
# 1994	8	9	DATE
# Saturday, U.N.	0	3	DATE
# Congo	12	13	GPE
# Rwandan	21	22	ORG
# Afghanistan	2	3	GPE
# 53 percent	21	23	PERCENT
# U.N	0	1	GPE
# Afghan	2	3	NORP
# Peter Erben	6	8	PERSON
# Thursday	9	10	DATE
# some 6.6 million	19	22	CARDINAL
# first	27	28	ORDINAL
# more than 30 years	31	35	DATE
# Sunday	3	4	DATE
# more than one million	7	11	CARDINAL
# last year's	14	17	DATE
#
# 	20	21	PERSON
# Taleban	18	19	ORG
# more than month	24	27	DATE
# U.S.	1	2	GPE
# General Motors	4	6	ORG
# annual	10	11	DATE
# GM	0	1	ORG
# Tuesday	1	2	DATE
# $38.7 billion	6	9	MONEY
# 2007	10	11	DATE
# a fourth- quarter	2	5	DATE
# $722 million	7	10	MONEY
# 74,000	13	14	CARDINAL
# hourly	14	15	TIME
# the United States	17	20	GPE
# General Motors	0	2	ORG
# North American	3	5	NORP
# GM	3	4	ORG
# earlier this month	5	8	DATE
# more than two	11	14	CARDINAL
# January	18	19	DATE
# one year ago	22	25	DATE
# White House	0	2	ORG
# Dana Perino	3	5	PERSON
# today	5	6	DATE
# GM	7	8	ORG
# Clinton	0	1	PERSON
# Bill	6	7	PERSON
# half	3	4	CARDINAL
# Pakistan	0	1	GPE
# Pakistan	7	8	GPE
# Khalid Kidwai	12	14	PERSON
# Saturday	18	19	DATE
# Pakistan	11	12	GPE
# al-Qaida	15	18	PERSON
# Taliban	19	20	ORG
# Pakistani	10	11	NORP
# recent months	17	19	DATE
# Pakistan	0	1	GPE
# about 50	5	7	CARDINAL
# U.S.	0	1	GPE
# Middle East	1	3	LOC
# George Mitchell	4	6	PERSON
# Israeli	9	10	NORP
# Benjamin Netanyahu	12	14	PERSON
# Jerusalem	15	16	GPE
# Thursday	16	17	DATE
# Mitchell	0	1	PERSON
# Wednesday	2	3	DATE
# Ramallah	4	5	GPE
# Palestinian	6	7	NORP
# Mahmoud Abbas	8	10	PERSON
# Palestinian	1	2	NORP
# Saeb Erekat	3	5	PERSON
# Palestinian	15	16	NORP
# Palestinians	1	2	NORP
# Israel	7	8	GPE
# the 1967 war	10	13	EVENT
# East Jerusalem	15	17	PERSON
# Israel	3	4	GPE
# Netanyahu	1	2	PERSON
# Palestinian	8	9	NORP
# East Jerusalem	16	18	GPE
# Mitchell	0	1	ORG
# four months	14	16	DATE
# Italian	0	1	NORP
# Taleban	3	4	ORG
# Italian	9	10	NORP
# Afghanistan	14	15	GPE
# three days	16	18	DATE
# Daniele Mastrogiacomo	0	2	PERSON
# Italy	6	7	GPE
# La Repubblica	8	10	GPE
# Sunday	13	14	DATE
# Kandahar	15	16	GPE
# Afghans	25	26	NORP
# Taleban	1	2	ORG
# Tuesday	4	5	DATE
# European	10	11	NORP
# British	17	18	NORP
# Mastrogiacomo	5	6	PERSON
# Italy	0	1	GPE
# Afghanistan	4	5	GPE
# Ettore Francesco Sequi	6	9	ORG
# the French Press Agency	11	15	ORG
# Wednesday	15	16	DATE
# Mastrogiacomo, 52	0	3	DATE
# Central Asia	9	11	LOC
# the Middle East	12	15	LOC
# La Repubblica	16	18	GPE
# 2002	19	20	DATE
# Afghan	0	1	NORP
# seven	3	4	CARDINAL
# Afghanistan	9	10	GPE
# Saturday	10	11	DATE
# Kunar	8	9	GPE
# Pakistani	11	12	NORP
# Taliban	0	1	ORG
# Kabul	10	11	GPE
# today	1	2	DATE
# Farah province	16	18	GPE
# Afghanistan	3	4	GPE
# Iran	5	6	GPE
# Iran	0	1	GPE
# 123-kilometer	5	6	CARDINAL
# Dogharoun	9	10	GPE
# Afghanistan	12	13	GPE
# Herat province	15	17	GPE
# Afghanistan	27	28	GPE
# Iranian	4	5	NORP
# Mohammad Khatami	6	8	PERSON
# Iran	9	10	GPE
# Afghanistan	17	18	GPE
# more than 30	8	11	CARDINAL
# Iran	16	17	GPE
# Afghanistan	22	23	GPE
# Central Asia	24	26	LOC
# Afghan	1	2	NORP
# Hamid Karzai	3	5	PERSON
# Iran	6	7	GPE
# $60 million	10	13	MONEY
# Afghanistan	23	24	GPE
# Karzai	1	2	PERSON
# two	12	13	CARDINAL
# France	2	3	GPE
# Germany	4	5	GPE
# Strasbourg	19	20	GPE
# Thursday	20	21	DATE
# NATO	24	25	ORG
# 60th	26	27	ORDINAL
# Several hundred	0	2	CARDINAL
# German	7	8	NORP
# Baden- Baden	10	12	PERSON
# U.S.	13	14	GPE
# Barack Obama	15	17	GPE
# German	18	19	NORP
# Angela Merkel	20	22	PERSON
# French	0	1	NORP
# Strasbourg	9	10	GPE
# 300	12	13	CARDINAL
# about 100	2	4	CARDINAL
# Strasbourg	28	29	GPE
# German	0	1	NORP
# French	2	3	NORP
# about 25,000	6	8	CARDINAL
# two	14	15	CARDINAL
# The African Union's	0	4	ORG
# Ivory Coast	10	12	LOC
# Thursday	3	4	DATE
# Ivory Coast	8	10	GPE
# AU	11	12	GPE
# Gbagbo	15	16	PERSON
# one year	19	21	DATE
# October 30 - the day	5	10	DATE
# Ivory Coast	18	20	GPE
# Ivory Coast	9	11	GPE
# United Nations	0	2	ORG
# Kofi Annan	5	7	PERSON
# Burma	16	17	GPE
# Aung San	28	30	PERSON
# Kyi	31	32	PERSON
# another six months	33	36	DATE
# Annan	4	5	PERSON
# Burma	15	16	GPE
# Kyi	3	4	PERSON
# the National League for Democracy	8	13	ORG
# 10	16	17	CARDINAL
# the past 16 years	18	22	DATE
# this month	7	9	DATE
# Mark Farmaner	0	2	PERSON
# Burma Campaign UK	3	6	ORG
# VOA	7	8	ORG
# Burmese	9	10	NORP
# Suu Kyi's	14	17	PERSON
# The United States	0	3	GPE
# the European Union	4	7	ORG
# Burma	11	12	GPE
# U.S.	0	1	GPE
# Beijing	3	4	GPE
# Chinese	7	8	NORP
# Hu Jintao	9	11	PERSON
# the United States	14	17	GPE
# April	18	19	DATE
# U.S.	4	5	GPE
# State	8	9	ORG
# Robert Zoellick	9	11	PERSON
# Beijing	13	14	GPE
# Chinese	18	19	NORP
# Zoellick	0	1	PERSON
# Chinese	3	4	NORP
# Wen Jiabao	5	7	PERSON
# Tuesday	7	8	DATE
# Li Zhaoxing	17	19	PERSON
# three-day	4	7	DATE
# Zoellick	9	10	PERSON
# Chengdu	18	19	GPE
# The United States	0	3	GPE
# France	4	5	GPE
# United Nations	13	15	ORG
# Lebanon	24	25	GPE
# New York	1	3	ORG
# Friday,	3	5	DATE
# U.N. Security Council	5	8	ORG
# Nana Effah-Apenteng	9	13	PERSON
# American	14	15	NORP
# French	16	17	NORP
# Monday	7	8	DATE
# U.S.	7	8	GPE
# French	9	10	NORP
# Israeli	25	26	NORP
# Israel	12	13	GPE
# Hezbollah	14	15	ORG
# Bush	17	18	PERSON
# French	19	20	NORP
# Jacques Chirac	21	23	PERSON
# U.N.	28	29	ORG
# Kofi Annan	32	34	PERSON
# Friday	34	35	DATE
# Egypt	3	4	GPE
# late Monday	13	15	DATE
# at least 31	25	28	CARDINAL
# about 30	31	33	CARDINAL
# Beni Suef	8	10	PERSON
# one	3	4	CARDINAL
# an hour	23	25	TIME
# Egypt	6	7	GPE
# Cairo	15	16	GPE
# more than 350	17	20	CARDINAL
# 2002	22	23	DATE
# Seoul	2	3	GPE
# South Korean	5	7	NORP
# one-third	14	17	CARDINAL
# Iraq	23	24	GPE
# year	34	35	DATE
# Roh Moo-hyun's	1	6	PERSON
# 1,000	11	12	CARDINAL
# the first half of next year	14	20	DATE
# the 3,200-strong South	3	6	ORG
# Iraq	9	10	GPE
# December 2006	14	16	DATE
# Roh	5	6	PERSON
# Parliament	17	18	ORG
# Wednesday	19	20	DATE
# South Korea's	0	3	GPE
# Iraqi	15	16	NORP
# Arbil	18	19	GPE
# 2004	20	21	DATE
# the United States	1	4	GPE
# Britain	5	6	GPE
# Seoul	7	8	GPE
# third	13	14	ORDINAL
# Iraq	18	19	GPE
# Ukraine	0	1	GPE
# Leonid Kuchma	11	13	PERSON
# Sunday	18	19	DATE
# Kuchma	1	2	PERSON
# Soviet	11	12	NORP
# about 200,000	4	6	CARDINAL
# Kiev	14	15	GPE
# Viktor Yushchenko - be	21	25	PERSON
# Russian	7	8	NORP
# Viktor Yanukovich	10	12	PERSON
# Kuchma	1	2	PERSON
# U.S.	0	1	GPE
# European	2	3	NORP
# Sunday	11	12	DATE
# Russian	0	1	NORP
# Vladimir Putin	2	4	PERSON
# European	5	6	NORP
# NATO	3	4	ORG
# Afghanistan	6	7	GPE
# Taleban	17	18	ORG
# Iraq	24	25	GPE
# David Richards	3	5	PERSON
# BBC	6	7	ORG
# Thursday	7	8	DATE
# Afghanistan	28	29	GPE
# British	1	2	NORP
# Iraq	7	8	GPE
# Afghanistan	9	10	GPE
# Afghanistan	0	1	GPE
# recent months	2	4	DATE
# U.S	11	12	GPE
# Taleban	17	18	ORG
# December 2001	20	22	DATE
# Osama bin Laden	30	33	PERSON
# Thursday	1	2	DATE
# 12	3	4	CARDINAL
# Taleban	5	6	ORG
# southern Nawzad	9	11	LOC
# first	1	2	ORDINAL
# Australia	8	9	GPE
# China	10	11	GPE
# Sydney	15	16	GPE
# two	6	7	CARDINAL
# China	10	11	GPE
# Australia	24	25	GPE
# China	3	4	GPE
# National People's Congress	5	9	ORG
# Monday	13	14	DATE
# two	18	19	CARDINAL
#
# 	25	26	TIME
# China	0	1	GPE
# Australia	2	3	GPE
# third	4	5	ORDINAL
# China	0	1	GPE
# Australian	8	9	NORP
# Australia	0	1	GPE
# the United States	8	11	GPE
# Thailand	12	13	GPE
# Singapore	14	15	GPE
# New Zealand	16	18	GPE
# China	0	1	GPE
# the United States	9	12	GPE
# the European Union	13	16	ORG
# Uganda	0	1	GPE
# Sudanese	19	20	NORP
# John Garang	22	24	PERSON
# Thursday	4	5	DATE
# Andrew Mwenda	8	10	PERSON
# Last week	0	2	DATE
# Uganda	3	4	GPE
# Broadcasting Council	5	7	ORG
# Mwenda	13	14	PERSON
# Garang	24	25	PERSON
# Mwenda	4	5	PERSON
# Ugandan	0	1	NORP
# nearly $3,000	9	12	MONEY
# Garang	1	2	PERSON
# July 30	5	7	DATE
# Sudan	12	13	GPE
# Ugandan	14	15	NORP
# Yoweri Museveni's	16	19	PERSON
# India	8	9	GPE
# Pakistan	10	11	GPE
# Kashmir	20	21	GPE
# month	26	27	DATE
# two	1	2	CARDINAL
# five	9	10	CARDINAL
# November 7	12	14	DATE
# U.N.	1	2	ORG
# Rashid Khalikov	9	11	PERSON
# Himalayan	4	5	ORG
# winter	5	6	DATE
# millions	8	9	CARDINAL
# 200,000	1	2	CARDINAL
# three weeks	9	11	DATE
# about 55,000	16	18	CARDINAL
# Pakistani	24	25	NORP
# Kashmir	25	26	PERSON
# Mexican	0	1	NORP
# two	11	12	CARDINAL
# Monterrey	20	21	GPE
# Enrique Barrios Rodriguez	0	3	PERSON
# early Monday	5	7	TIME
# morning	7	8	TIME
# just a day	2	5	DATE
# Reynaldo Ramos	10	12	PERSON
# Monterrey	0	1	GPE
# Fernando Larrazabal	2	4	PERSON
# Monterrey	0	1	GPE
# Mexican	6	7	NORP
# Nuevo Leon	9	11	GPE
# The United Nations	0	3	ORG
# tens of thousands	6	9	CARDINAL
# Tuesday	7	8	DATE
# the U.N. Environment Program	12	16	ORG
# Nairobi	18	19	GPE
# Kenya	20	21	GPE
# U.N.	1	2	ORG
# Bird	0	1	PERSON
# more than 100	4	7	CARDINAL
# 2003	9	10	DATE
# East Asia	13	15	LOC
# Africa	11	12	LOC
# the Middle East	13	16	LOC
# Europe	17	18	LOC
# Kyrgyzstan	3	4	GPE
# Osh	19	20	GPE
# four	22	23	CARDINAL
# Bayaman Erkinbayev	11	13	PERSON
# six weeks ago	24	27	DATE
# Monday	0	1	DATE
# Osh	4	5	PERSON
# Kara-Suu Thursday	18	22	GPE
# Erkinbayev	25	26	PERSON
# Kyrgyzstan	0	1	GPE
# Central Asian	4	6	NORP
# Askar Akayev's	13	16	PERSON
# March	18	19	DATE
# Akayev	5	6	PERSON
# July 10	9	11	DATE
# Erkinbayev	1	2	PERSON
# one	3	4	CARDINAL
# Ecuador	0	1	GPE
# more than half	13	16	CARDINAL
# approximately one-third	23	27	CARDINAL
# recent years	32	34	DATE
# 1999/2000	1	2	CARDINAL
# Ecuador	3	4	GPE
# 5.3%.	14	16	PERCENT
# Poverty	0	1	GPE
# Ecuador	10	11	GPE
# March 2000	1	3	DATE
# Congress	5	6	ORG
# US	20	21	GPE
# the years	10	12	DATE
# 2002-06	1	4	DATE
# 5.2% per year	10	13	PERCENT
# five-year	16	19	DATE
# 25 years	21	23	DATE
# 2007	4	5	DATE
# 7.2% in	13	15	PERCENT
# 2008	15	16	DATE
# Rafael CORREA	1	3	PERSON
# January 2007	8	10	DATE
# December 2008	13	15	DATE
# Ecuador	16	17	GPE
# approximately US$3.2 billion	29	33	MONEY
# about 80% of	35	38	PERCENT
# Ecuador	38	39	GPE
# May 2009	1	3	DATE
# Ecuador	4	5	GPE
# 91% of	7	9	PERCENT
# CORREA	4	5	LAW
# late 2009	11	13	DATE
# 13	18	19	CARDINAL
# one	24	25	CARDINAL
# the United States	26	29	GPE
# Ecuadorian	1	2	NORP
# 0.4% in	4	6	PERCENT
# 2009	6	7	DATE
# 3.7% rate	5	7	PERCENT
# 2010	8	9	DATE
# Ecuadorian	12	13	NORP
# Burmese	1	2	NORP
# Rangoon	10	11	GPE
# U.S.	31	32	GPE
# Burmese	4	5	NORP
# Ministries of Agriculture	12	15	ORG
# Defense, Energy and	16	20	ORG
# Pyinmana	24	25	GPE
# over 150 kilometers	27	30	QUANTITY
# Rangoon	32	33	GPE
# a few months	35	38	DATE
# Pyinmana	0	1	PERSON
# Burma	4	5	GPE
# Burma	11	12	GPE
# Japanese	17	18	NORP
# World War II	20	23	EVENT
# Communist	34	35	NORP
# Iraq	8	9	GPE
# the United States	13	16	GPE
# Bernie Mac	0	2	ORG
# 30 years	13	15	DATE
#
# 	16	17	CARDINAL
# 49-year-old	1	4	DATE
# Bernard McCullogh - made	8	12	PERSON
# Monday March 19	14	17	DATE
# David Letterman's	18	21	PERSON
# U.S.	21	22	GPE
# Later this year	0	3	DATE
# The Whole Truth	12	15	ORG
# Mac	24	25	PERSON
# Bernie Mac's	0	3	ORG
# Pride	9	10	ORG
# March 23	12	14	DATE
# the United States	15	18	GPE
# Germany	2	3	GPE
# two	4	5	CARDINAL
# Thursday	13	14	DATE
# last month's	30	33	DATE
#
# 	41	42	PERSON
# Wednesday	3	4	DATE
# third	5	6	ORDINAL
# Christian	11	12	NORP
# Democratic	12	13	NORP
# Angela Merkel	14	16	PERSON
# Gerhard Schroeder	18	20	PERSON
# Social Democrats	25	27	NORP
# Merkel	1	2	PERSON
# Democrats	2	3	NORP
# Schroeder	7	8	PERSON
# the Christian Democrats	13	16	ORG
# Wednesday	3	4	DATE
# 34 percent	5	7	PERCENT
# Germans	8	9	NORP
# Merkel	11	12	PERSON
# 26 percent	15	17	PERCENT
# Schroeder	19	20	PERSON
# at least 14	6	9	CARDINAL
# Baghdad	11	12	GPE
# Iraq	23	24	GPE
# U.S	29	30	GPE
# Iraqi	34	35	NORP
# more than 30	2	5	CARDINAL
# Thursday	19	20	DATE
# the Karrada neighborhood	6	9	LOC
# At least 10	0	3	CARDINAL
# 17	6	7	CARDINAL
# Iraqi	3	4	NORP
# five days ago	28	31	DATE
# Iraqi	3	4	NORP
# 27	6	7	CARDINAL
# Wednesday	17	18	DATE
# Russian	0	1	NORP
# four to six years	10	14	DATE
# first	11	12	ORDINAL
# Friday	13	14	DATE
# two	6	7	CARDINAL
# Dmitri Medvedev	14	16	PERSON
# last week	16	18	DATE
# Russian	7	8	NORP
# Vladimir Putin	9	11	PERSON
# Russia	15	16	GPE
# Medvedev	1	2	PERSON
# the State Duma	9	12	ORG
# four to	13	15	TIME
# Australian	0	1	NORP
# John Howard	3	5	PERSON
# Margaret Hassan	13	15	PERSON
# Iraq	16	17	GPE
# Howard	1	2	PERSON
# Thursday	6	7	DATE
# Canberra	8	9	GPE
# Fallujah	17	18	GPE
# Hassan	24	25	PERSON
# Howard	9	10	PERSON
# Hassan	21	22	PERSON
# Sunday	1	2	DATE
# U.S.	3	4	GPE
# Fallujah	6	7	GPE
# Western	17	18	NORP
# Arabic	3	4	ORG
# al-Jazeera	6	9	ORG
# Hassan	4	5	PERSON
# last month	5	7	DATE
# Britain	10	11	GPE
# Iraq	16	17	GPE
# Hassan	1	2	PERSON
# Iraqi	3	4	NORP
# CARE	9	10	ORG
# Australian	18	19	NORP
# Mexico	5	6	GPE
# Coretta Scott King	7	10	PERSON
# Mexico	4	5	GPE
# Baja California	6	8	GPE
# the Hospital Santa Monica	13	17	ORG
# Thursday	17	18	DATE
# some 26 kilometers	10	13	QUANTITY
# San Diego	15	17	GPE
# the Atlanta Journal-Constitution	6	11	ORG
# Friday	12	13	DATE
# King	15	16	PERSON
# January 26	5	7	DATE
# sustained last year	21	24	DATE
# U.S.	0	1	GPE
# Iraq	4	5	GPE
# at least 21	6	9	CARDINAL
# three	14	15	CARDINAL
# Baghdad	18	19	GPE
# two	9	10	CARDINAL
# Iraqis	16	17	NORP
# U.S.	21	22	GPE
# Tikrit	24	25	GPE
# 17	27	28	CARDINAL
# 13	31	32	CARDINAL
# at least three	8	11	CARDINAL
# Iraqi National Guardsmen	11	14	ORG
# Tikrit	16	17	GPE
# Iraqi	3	4	NORP
# Samarra	14	15	GPE
# U.S.	5	6	GPE
# Fallujah	20	21	GPE
# Baghdad	7	8	GPE
# last month	10	12	DATE
# U.S.	17	18	GPE
# first	4	5	ORDINAL
# Senate	0	1	ORG
# Democrats	1	2	NORP
# Bush	5	6	PERSON
# U.S. Supreme Court	17	20	ORG
# Senate	0	1	ORG
# Harry Reid	3	5	PERSON
# Ronald Reagan	26	28	PERSON
# O'Connor	33	34	PERSON
# Senate	5	6	ORG
# Ted Kennedy	1	3	PERSON
# Democrats	4	5	NORP
# American	23	24	NORP
# Bush	1	2	PERSON
# Senate	3	4	ORG
# Democrats	4	5	NORP
# earlier this year	10	13	DATE
# U.S.	21	22	GPE
# Supreme Court	1	3	ORG
# Senate	10	11	ORG
# Republicans	0	1	NORP
# Senate	3	4	ORG
# 55-to-45	6	7	CARDINAL
# the United Nations	3	6	ORG
# Kosovo	8	9	GPE
# Belgrade	11	12	GPE
# two days	13	15	DATE
# Serbian	19	20	NORP
# U.N.	0	1	ORG
# Soren Jessen-Petersen	2	6	PERSON
# Sunday	7	8	DATE
# Serbia	9	10	GPE
# Vuk Draskovic	15	17	PERSON
# Draskovic	6	7	PERSON
# Serb	19	20	NORP
# Monday	1	2	DATE
# Jessen-Petersen	4	7	PERSON
# Serbian	12	13	NORP
# Boris Tadic	14	16	PERSON
# Vojislav Kostunica	19	21	PERSON
# Kosovo	7	8	GPE
# Albanian	10	11	NORP
# Serbian	15	16	NORP
# later this year	21	24	DATE
# Kosovo	0	1	GPE
# Albanian	3	4	NORP
# Serb	10	11	NORP
# Serbia	19	20	GPE
# U.N.	1	2	ORG
# since 1999	7	9	DATE
# China	0	1	GPE
# the United States	7	10	GPE
# North Korea	11	13	GPE
# China	15	16	GPE
# Beijing	18	19	GPE
# this week	19	21	DATE
# six	26	27	CARDINAL
# Pyongyang	31	32	GPE
# Chinese	1	2	NORP
# Thursday	6	7	DATE
# Wednesday	7	8	DATE
# U.S.	13	14	GPE
# Christopher Hill	20	22	PERSON
# Wednesday	0	1	DATE
# North Korea's	2	5	GPE
# Kim Jong	10	12	PERSON
# China	15	16	GPE
# Chinese	21	22	NORP
# Hu Jintao	23	25	PERSON
# Kim	6	7	PERSON
# six	21	22	CARDINAL
# Pyongyang	0	1	GPE
# the United States	4	7	GPE
# first	7	8	ORDINAL
# North Korea	12	14	GPE
# Washington	0	1	GPE
# U.S.	1	2	GPE
# F-16	12	13	ORDINAL
# Iraq	18	19	GPE
# Monday	19	20	DATE
# Baghdad	12	13	GPE
# U.S.	14	15	GPE
# The Air Force	0	3	ORG
# Air Force	0	2	ORG
# Colombia	3	4	GPE
# Fernando Araujo	2	4	PERSON
# Monday	5	6	DATE
# Venezuelan	12	13	NORP
# Hugo Chavez	14	16	PERSON
# Araujo	0	1	ORG
# Chavez	3	4	PERSON
# late December	1	3	DATE
# Chavez	4	5	PERSON
# three	13	14	CARDINAL
# the Revolutionary Armed Forces of	17	22	ORG
# Colombia	22	23	GPE
# FARC	24	25	GPE
# New Year's Eve	1	5	EVENT
# FARC	13	14	GPE
# Colombian	15	16	NORP
# one	5	6	CARDINAL
# three-year-old	11	16	DATE
# FARC	25	26	GPE
# 2005	32	33	DATE
# Amnesty International	4	6	ORG
# Israel	13	14	GPE
# Palestinians	15	16	NORP
# West Bank	19	21	GPE
# Gaza Strip	22	24	GPE
# Tuesday	4	5	DATE
# Israel	7	8	GPE
# the West Bank	22	25	GPE
# Amnesty	2	3	ORG
# Israelis	11	12	NORP
# four	13	14	CARDINAL
# Palestinians	19	20	NORP
# the World Health Organization	31	35	ORG
# Israeli	0	1	NORP
# Amnesty	4	5	ORG
# Palestinians	7	8	NORP
# Israel	5	6	GPE
# Palestinian	8	9	NORP
# American	2	3	NORP
# Iraqi	12	13	NORP
# Kirkuk	15	16	GPE
# hundreds	18	19	CARDINAL
# Arabs	20	21	NORP
# Turkmens - sometimes	22	25	CARDINAL
# U.S.	29	30	GPE
# U.S.	1	2	GPE
# theWashington Post	9	11	ORG
# Kurdish	21	22	NORP
# Kurdish	32	33	NORP
# Iraq	36	37	GPE
# U.S. State Department	8	11	ORG
# the White House	14	17	ORG
# the Defense Department	18	21	ORG
# the U.S. Embassy	22	25	ORG
# Baghdad	26	27	GPE
# three	4	5	CARDINAL
# Iraqi	5	6	NORP
# Arabs	11	12	NORP
# Turkmens	13	14	NORP
# recent months	17	19	DATE
# Philippines	4	5	GPE
# 50	22	23	CARDINAL
# more than 40	25	28	CARDINAL
# Friday	3	4	DATE
# Zamoanga	8	9	GPE
# Sur province	10	12	GPE
# 19	12	13	CARDINAL
# U.S.	14	15	GPE
# May 4	17	19	DATE
# French	0	1	NORP
# 13th	7	8	ORDINAL
# night	8	9	TIME
# night	13	14	TIME
# more than 600	5	8	CARDINAL
# about half	13	15	CARDINAL
# night	19	20	TIME
# 204	2	3	CARDINAL
# Muslim	18	19	NORP
# North African	21	23	NORP
# midnight	8	9	TIME
# Amiens	13	14	GPE
# Orleans	15	16	NORP
# Paris	18	19	GPE
# Savigny-sur-Orge	21	26	ORG
# Lyon	5	6	GPE
# one	18	19	CARDINAL
# late Tuesday	20	22	DATE
# Dominique de Villepin Tuesday	2	6	PERSON
# French	15	16	NORP
# New Orleans	7	9	GPE
# The Associated Press	0	3	ORG
# two	6	7	CARDINAL
# New Orleans	4	6	GPE
# U.S.	0	1	GPE
# New Orleans	1	3	GPE
# SOS	8	9	ORG
# HAMSAT	8	9	ORG
# Sriharokota	19	20	GPE
# India	21	22	GPE
# India	22	23	GPE
# two	28	29	CARDINAL
# the Polar Satellite Launch Vehicle	8	13	ORG
# PSLAV	15	16	ORG
# India	19	20	GPE
# Sriharokota	23	24	GPE
# the Bay of Bengal	28	32	LOC
# Thursday	32	33	DATE
# two	2	3	CARDINAL
# high-	12	13	CARDINAL
# HAMSAT	2	3	ORG
# Indian	0	1	NORP
# PSLAV	12	13	ORG
# 2008	24	25	DATE
# Two	0	1	CARDINAL
# Lebanese	1	2	NORP
# Islamic	15	16	NORP
# Palestinian	21	22	NORP
# Army	0	1	ORG
# Wednesday	7	8	DATE
# the Nahr	9	11	ORG
# Lebanon	18	19	GPE
# More than 130	0	3	CARDINAL
# 63	6	7	CARDINAL
# at least 20	9	12	CARDINAL
# Lebanese	20	21	NORP
# Fatah	26	27	ORG
# more than three weeks ago	35	40	DATE
# Tens of thousands	0	3	CARDINAL
# Palestinian	4	5	NORP
# U.S	5	6	GPE
# Human Rights Watch	10	13	ORG
# Lebanese	16	17	NORP
# Lebanese	0	1	NORP
# U.S.	0	1	GPE
# Iraqi	2	3	NORP
# Anbar province	13	15	GPE
# Baghdad	18	19	GPE
# American	0	1	NORP
# Sunday	9	10	DATE
# the Euphrates River	14	17	LOC
# Ramadi	19	20	PERSON
# Indonesian	5	6	NORP
# Monday	9	10	DATE
# Iraq	13	14	GPE
# two	16	17	CARDINAL
# Indonesian	17	18	NORP
# last week	22	24	DATE
# Iraqi	2	3	NORP
# Mosul	9	10	GPE
# late Sunday	22	24	DATE
# al-Qaida	6	9	ORG
# al-Jazeera	13	16	ORG
# 2	15	16	CARDINAL
# Ayman al-Zawahiri	18	22	PERSON
# U.S.	24	25	GPE
# Muslim	30	31	NORP
# Ukrainian	0	1	NORP
# Viktor Yushchenko	2	4	PERSON
# Tuesday	10	11	DATE
# Monday	13	14	DATE
# Viktor Yanukovych	17	19	PERSON
# Russian Party of Regions	26	30	ORG
# the past week	11	14	DATE
# March	16	17	DATE
# three	9	10	CARDINAL
# 2004	14	15	DATE
# Orange Revolution	15	17	EVENT
# Yushchenko	20	21	PERSON
# Iran	0	1	GPE
# U.N.	6	7	ORG
# Iranian	21	22	NORP
# Israel	26	27	GPE
# Saturday	4	5	DATE
# Iran	5	6	GPE
# Iranian	0	1	NORP
# Mahmoud Ahmadinejad	2	4	PERSON
# Wednesday	9	10	DATE
# Israel	12	13	GPE
# Friday	5	6	DATE
# Israeli	10	11	NORP
# Tehran	13	14	GPE
# Palestinian	0	1	NORP
# Saeb Erekat	3	5	PERSON
# Palestinians	6	7	NORP
# Israel	9	10	GPE
# Palestinian	12	13	NORP
# Israel	20	21	GPE
# Friday	0	1	DATE
# the U.N. Security Council	2	6	ORG
# Iranian	8	9	NORP
# first	1	2	ORDINAL
# United Nations	4	6	ORG
# Burundi	9	10	GPE
# 12-month	15	16	ORDINAL
# African	21	22	NORP
# U.N.	0	1	GPE
# some 170	3	5	CARDINAL
# Mozambican	5	6	NORP
# Saturday	8	9	DATE
# Bujumbura	16	17	PERSON
# The United Nations	0	3	ORG
# Burundi	11	12	GPE
# 40 percent	13	15	PERCENT
# April	16	17	DATE
# Kenyans	6	7	NORP
# Ethiopians	11	12	NORP
# U.N.	0	1	ORG
# Burundi	5	6	GPE
# 2004	7	8	DATE
# 300,000	1	2	CARDINAL
# Hutu	10	11	NORP
# Tutsis	16	17	GPE
# Haiti	0	1	GPE
# Jean- Bertrand Aristide	12	15	PERSON
# Gerard Latortue	2	4	PERSON
# Friday	5	6	DATE
# the Justice Ministry	13	16	ORG
# Aristide	1	2	PERSON
# South Africa	6	8	GPE
# Latortue	1	2	PERSON
# Aristide	17	18	PERSON
# Haiti	21	22	GPE
# February	27	28	DATE
# Aristide	1	2	PERSON
# Miami	3	4	GPE
# Ira Kurzban	8	10	PERSON
# Kurzban	1	2	PERSON
# VOA	4	5	ORG
# American Andy Roddick	0	3	ORG
# Czech Tomas Berdych	4	7	ORG
# David Ferrer	9	11	PERSON
# the Association of Tennis Professionals	18	23	ORG
# London	30	31	GPE
# Spaniard Rafael Nadal	5	8	ORG
# Roger Federer	10	12	PERSON
# Serbian	13	14	NORP
# Novak Djokovic	14	16	PERSON
# Scott Andy Murray	17	20	PERSON
# Robin Soderling	22	24	PERSON
# eight	26	27	CARDINAL
# November 21-28	34	38	DATE
# first	4	5	ORDINAL
# season	8	9	DATE
# 2010	11	12	DATE
# Berdych	14	15	PERSON
# Frenchman Gael Monfils	6	9	PERSON
# third	11	12	ORDINAL
# Spain	16	17	GPE
# Fernando Verdasco	18	20	PERSON
# the Paris Masters	21	24	ORG
# Russian	0	1	NORP
# Argentine Juan Martin del Potro	4	9	PERSON
# 2009	12	13	DATE
# year	6	7	DATE
# Tuesday	6	7	DATE
# Turkish	13	14	NORP
# Iraq	17	18	GPE
# Kurdish	20	21	NORP
# U.S.	3	4	GPE
# November	6	7	DATE
# 1.48	11	12	MONEY
# a record $	13	16	MONEY
# 87.61	16	17	MONEY
# as high as	5	8	PERCENT
# 88.20	9	10	MONEY
# Iraqi	13	14	NORP
# Iraq	23	24	GPE
# the United States	14	17	GPE
# winter	23	24	DATE
# Tuesday	3	4	DATE
# OPEC	11	12	ORG
# Abdullah Al- Badri	13	16	PERSON
# Hong Kong	0	2	GPE
# 944	5	6	CARDINAL
# last week's	13	16	DATE
# World Trade Organization	16	19	ORG
# More than 1000	0	3	CARDINAL
# South Korean	4	6	NORP
# Saturday	1	2	DATE
# Hong Kong	0	2	GPE
# 14	7	8	CARDINAL
# Nearly 200	0	2	CARDINAL
# South Korea's	0	3	GPE
# Deputy Foreign Minister	3	6	ORG
# Lee Kyu-hyung	6	10	PERSON
# Hong Kong	12	14	GPE
# Monday	14	15	DATE
# Iraq	0	1	GPE
# 93	9	10	CARDINAL
# al-Qaida	13	16	ORG
# Anbar province	20	22	GPE
#
# 	23	24	GPE
# Major General	5	7	ORG
# Mohammed al-Askari	7	11	PERSON
# Thursday	13	14	DATE
# 60	17	18	CARDINAL
# late Tuesday	11	13	DATE
# Earlier this week	0	3	DATE
# Iraqi	4	5	NORP
# Nouri al-Maliki	7	11	PERSON
# one	14	15	CARDINAL
# Iraqi	2	3	NORP
# late Wednesday	3	5	TIME
# Baghdad	6	7	GPE
# The United States	0	3	GPE
# Britain	4	5	GPE
# Lagos	12	13	GPE
# Nigeria	14	15	GPE
# Claudia Annyaso	5	7	PERSON
# U.S.	10	11	GPE
# Abuja	13	14	GPE
# VOA	15	16	ORG
# Friday	16	17	DATE
# U.S.	19	20	GPE
# Lagos	22	23	GPE
# U.S.	37	38	GPE
# Nigerian	39	40	NORP
# British	0	1	NORP
# High Commission	8	10	ORG
# Lagos	12	13	GPE
# al-Qaida	4	7	PERSON
# Osama Bin Laden	8	11	PERSON
# Nigeria	13	14	GPE
# Nigeria	0	1	GPE
# Africa	7	8	LOC
# only two	3	5	CARDINAL
# Gabon	9	10	GPE
# France	14	15	GPE
# 1960	16	17	DATE
# Gabon	4	5	GPE
# El Hadj	6	8	ORG
# one	12	13	CARDINAL
# four decades	33	35	DATE
# BONGO	1	2	PERSON
# the early 1990s	12	15	DATE
# 2002-03	10	13	DATE
# 2005	18	19	DATE
# Gabon	27	28	GPE
# BONGO	1	2	PERSON
# June 2009	4	6	DATE
# August 2009	3	5	DATE
# Ali Ben BONGO	6	9	PERSON
# Gabon	19	20	GPE
# one	20	21	CARDINAL
# African	27	28	NORP
# January 2010	1	3	DATE
# Gabon	4	5	GPE
# the UN Security Council	10	14	ORG
# 2010-11	16	19	DATE
# Pakistani	4	5	NORP
# Benazir Bhutto	7	9	PERSON
# India	16	17	GPE
# Pakistan	18	19	GPE
# Asif Ali Zardari	0	3	PERSON
# the Pakistan People's Party	6	11	ORG
# Kashmir	22	23	LOC
# two	26	27	CARDINAL
# India	9	10	GPE
# CNN	11	12	ORG
# Friday	16	17	DATE
# Kashmir	0	1	ORG
# India	4	5	GPE
# Pakistan	6	7	GPE
# two	1	2	CARDINAL
# two	5	6	CARDINAL
# Himalayan mountain	14	16	LOC
# India	4	5	GPE
# Pakistan	6	7	GPE
# Kashmir	14	15	LOC
# Indian	2	3	NORP
# Kashmir	5	6	LOC
# India	9	10	GPE
# Pakistan	11	12	GPE
# 2004	18	19	DATE
# Ted Onulak	1	3	PERSON
# Charlie Parker	19	21	PERSON
# John Lee Hooker	22	25	PERSON
# VOA	0	1	ORG
# Tetiana Koprowicz	2	4	PERSON
# Jim Bertel	0	2	PERSON
# The European Union	0	3	ORG
# $195 million	6	9	MONEY
# 10	13	14	CARDINAL
# African	14	15	NORP
# Sudan	18	19	GPE
# the Democratic Republic of Congo	20	25	GPE
# Louis Michel	3	5	PERSON
# millions	6	7	CARDINAL
# Africans	8	9	NORP
# Nearly $57 million	0	4	MONEY
# Sudan	13	14	GPE
# Darfur	18	19	GPE
# $45 million	22	25	MONEY
# Congo	40	41	GPE
# Uganda	10	11	GPE
# Burundi	12	13	GPE
# Comoros	14	15	GPE
# Liberia	16	17	GPE
# Ivory Coast	18	20	GPE
# Madagascar	21	22	GPE
# Chad	23	24	GPE
# Tanzania	25	26	GPE
# the United Nations	12	15	ORG
# Red Cross	16	18	ORG
# Iran	6	7	GPE
# Saturday	8	9	DATE
# 5.7	14	15	CARDINAL
# at least 170	23	26	CARDINAL
# Iranian	0	1	NORP
# Saturday	4	5	DATE
# 5.7	9	10	CARDINAL
# The U.S. Geological Survey	0	4	ORG
# 5.3	10	11	CARDINAL
# the Negar region	3	6	LOC
# Kerman province	7	9	GPE
# mid-morning	10	13	TIME
# The U.S. Geological Survey	0	4	ORG
# Friday	5	6	DATE
# Torbat	15	16	GPE
# Iran	0	1	GPE
# Iran	5	6	GPE
# 2003	8	9	DATE
# about 30,000	11	13	CARDINAL
# Bam	23	24	GPE
# John Bolton	0	2	PERSON
# Senate	4	5	ORG
# Bush	6	7	PERSON
# U.S.	10	11	GPE
# the United Nations	13	16	ORG
# Monday	24	25	DATE
# John Bolton	5	7	PERSON
# the United Nations	15	18	ORG
# Senate	1	2	ORG
# Democrats	2	3	NORP
# Bolton	8	9	PERSON
# Democrats	0	1	NORP
# Bolton	10	11	PERSON
# State Department	12	14	ORG
# Cuba	21	22	GPE
# Bolton	4	5	PERSON
# Christopher Dodd	1	3	PERSON
# Bolton	1	2	PERSON
# Wednesday	4	5	DATE
# one	3	4	CARDINAL
# Kim Clijsters	8	10	PERSON
# ...
# Jews	2	3	NORP
# Sunday	13	14	DATE
# Jewish	21	22	NORP
# temples 2000 years ago	22	26	DATE
# Muslim	0	1	NORP
# Hamas	2	3	ORG
# Gaza	5	6	GPE
# Saturday	11	12	DATE
# Israel	19	20	GPE
# The Palestinian Authority	0	3	ORG
# today	13	14	DATE
# Israel	22	23	GPE
# Gaza	26	27	GPE
# this week	28	30	DATE
# Sudan	3	4	GPE
# Saturday	10	11	DATE
# at least 13	17	20	CARDINAL
# Unity State	10	12	ORG
# Friday	12	13	DATE
# Paulino Matip	26	28	PERSON
# Sudan	5	6	GPE
# Sudan Peoples'	10	13	PERSON
# SPLM	16	17	ORG
# Unity State	26	28	GPE
# July	21	22	DATE
# Southern Sudan	0	2	ORG
# North	11	12	LOC
# 2011	14	15	DATE
# 2005	7	8	DATE
# 21 years	18	20	DATE
# French	0	1	NORP
# Henri Salvador	2	4	PERSON
# Django Reinhardt	8	10	PERSON
# Paris	21	22	GPE
# Wednesday	22	23	DATE
# the age of 90	25	29	DATE
# Salvador	6	7	GPE
# French Guiana	4	6	ORG
# Paris	9	10	GPE
# Django Reinhardt	2	4	PERSON
# the 1930s	7	9	DATE
# Ray Ventura	6	8	PERSON
# Salvador	0	1	PERSON
# Dans mon Isle	4	7	WORK_OF_ART
# Brazilian	10	11	NORP
# Antonio Carlos Jobim	12	15	PERSON
# Afghanistan	6	7	GPE
# the United Nations	15	18	ORG
# late Tuesday	6	8	DATE
# the U.N. Human Rights Commission	10	15	ORG
# Afghanistan	17	18	GPE
# U.N.	1	2	ORG
# annual	6	7	DATE
# Geneva	9	10	GPE
# this week	10	12	DATE
# U.S	1	2	GPE
# Afghanistan	14	15	GPE
# the United States	3	6	GPE
# Afghanistan	13	14	GPE
# September	32	33	DATE
# Saudi Arabia	2	4	GPE
# three	6	7	CARDINAL
# Monday	12	13	DATE
# the U.S. Consulate	17	20	ORG
# Jeddah	21	22	GPE
# Saudi Interior Ministry	1	4	ORG
# three	6	7	CARDINAL
# al-Qaida	16	19	PERSON
# Saudi	22	23	NORP
# last year	24	26	DATE
# fourth	7	8	ORDINAL
# fifth	16	17	ORDINAL
# Saudi	12	13	NORP
# Five	0	1	CARDINAL
# The United States	0	3	GPE
# Saudi Arabia	13	15	GPE
# Monday	17	18	DATE
# Jeddah	1	2	PERSON
# Tuesday	5	6	DATE
# Thailand	0	1	GPE
# last month	21	23	DATE
# Thursday	2	3	DATE
# Air Force	10	12	ORG
# 2,000	5	6	CARDINAL
# a National Assembly	8	11	ORG
# 100	14	15	CARDINAL
# one year	15	17	DATE
# October of next year	22	26	DATE
# Surayud Chulanont	3	5	PERSON
# Thursday	5	6	DATE
# one year	19	21	DATE
# Thirapat Serirangsan	9	11	PERSON
# as many as 17	18	22	CARDINAL
# Venezuelan	0	1	NORP
# Hugo Chavez	2	4	PERSON
# U.S.	7	8	GPE
# George W. Bush	9	12	PERSON
# Colombia	24	25	GPE
# three	27	28	CARDINAL
# Americans	28	29	NORP
# Chavez	1	2	PERSON
# a year ago	6	9	DATE
# Bush	11	12	PERSON
# United Nations	18	20	ORG
# Tuesday	23	24	DATE
# the United States	24	27	GPE
# Caracas	7	8	GPE
# three	12	13	CARDINAL
# Americans	13	14	NORP
# Marxist	17	18	NORP
# Colombia	20	21	GPE
# 2003	22	23	DATE
# U.S. State Department	0	3	ORG
# Thomas Howe	4	6	PERSON
# Keith Stansell	7	9	PERSON
# Marc Gonsalvez	10	12	PERSON
# Colombia	0	1	GPE
# FARC	8	9	GPE
# hundreds	11	12	CARDINAL
# three	20	21	CARDINAL
# Americans	21	22	NORP
# Two	0	1	CARDINAL
# FARC	4	5	GPE
# the United States	10	13	GPE
# U.S.	0	1	GPE
# Nobel	9	10	WORK_OF_ART
#
# 	27	28	ORG
# Stephen Chu	0	2	PERSON
# the Lawrence Berkeley National Laboratory	6	11	ORG
# California	12	13	GPE
# 1997	18	19	DATE
# Nobel Peace Prize	19	22	WORK_OF_ART
# Chu	4	5	PERSON
# recent years	26	28	DATE
# Obama	1	2	PERSON
# Lisa Jackson	4	6	PERSON
# the Environmental Protection Agency	8	12	ORG
# Jackson	0	1	PERSON
# the Department of Environmental Protection	6	11	ORG
# New Jersey	16	18	GPE
# the New Jersey	8	11	ORG
# Jackson	0	1	PERSON
# first	4	5	ORDINAL
# African-	5	7	NORP
# EPA	11	12	ORG
# Thursday	9	10	DATE
# Senate	14	15	ORG
# Democratic	15	16	NORP
# Tom Daschle	17	19	PERSON
# At least 125	0	3	CARDINAL
# India	20	21	GPE
# 89	9	10	CARDINAL
# Bombay	17	18	ORG
# Mumbai	22	23	PERSON
# more than 1,000	6	9	CARDINAL
# about two weeks ago	17	21	DATE
# More than 4,000	0	3	CARDINAL
# Israeli	6	7	NORP
# two	10	11	CARDINAL
# Palestinians	11	12	NORP
# at least seven	14	17	CARDINAL
# Wednesday	18	19	DATE
# the Gaza Strip	20	23	GPE
# The Islamic Jihad	0	3	ORG
# one	4	5	CARDINAL
# two	7	8	CARDINAL
# At least one	0	3	CARDINAL
# Israeli	1	2	NORP
# Gaza	21	22	GPE
# April	1	2	DATE
# Israel	3	4	GPE
# Gaza	16	17	GPE
# Palestinians	18	19	NORP
#
# 	26	27	TIME
# Silvan Shalom	3	5	PERSON
# Israeli	13	14	NORP
# Hamas	23	24	ORG
# Gaza	26	27	GPE
# U.S.	1	2	GPE
# three	10	11	CARDINAL
# 1998	17	18	DATE
# two	20	21	CARDINAL
# U.S.	21	22	GPE
# Africa	24	25	LOC
# Second	1	2	ORDINAL
# U.S. Circuit Court of Appeals	2	7	ORG
# Monday	8	9	DATE
# Four	0	1	CARDINAL
# 2001	5	6	DATE
# August 7, 1998	8	12	DATE
# U.S.	14	15	GPE
# Nairobi	17	18	GPE
# Kenya	19	20	GPE
# Dar es Salaam	22	25	ORG
# Tanzania	26	27	GPE
# 224	3	4	CARDINAL
# Africans	9	10	NORP
# thousands	13	14	CARDINAL
# 12	0	1	CARDINAL
# Americans	1	2	NORP
# One	0	1	CARDINAL
# four	3	4	CARDINAL
# Osama bin Laden's al-Qaida	5	12	PERSON
# Bin Laden	0	2	PERSON
# BOY	1	2	ORG
# Scorpion	11	12	EVENT
# Scorpion	1	2	ORG
# Thirty-four	0	3	CARDINAL
# Cuban	3	4	NORP
# Cuba	10	11	GPE
# the United States	12	15	GPE
# a week	20	22	DATE
# Coast Guard	24	26	ORG
# Friday	5	6	DATE
# Coast Guard	6	8	ORG
# since November 5	10	13	DATE
# eight-meter	16	19	QUANTITY
# Two	0	1	CARDINAL
# 34	1	2	CARDINAL
# Cuba	5	6	GPE
# 45	8	9	CARDINAL
# The United States	0	3	GPE
# Cuban	5	6	NORP
# U.S.	11	12	GPE
#
# 	27	28	ORG
# U.S.	0	1	GPE
# Washington	3	4	GPE
# Eritrea 90 days	6	9	DATE
# California	18	19	GPE
# U.S.	1	2	GPE
# U.S.	22	23	GPE
# Eritrea	25	26	GPE
# Eritrea	18	19	GPE
# U.S	0	1	GPE
# recent months	7	9	DATE
# Eritrea	10	11	GPE
# Washington	13	14	GPE
# Ethiopia	22	23	GPE
# U.S.	1	2	GPE
# Asmara	4	5	GPE
# January	10	11	DATE
# Eritrea	13	14	GPE
# Eritrea	5	6	GPE
# the United Nations	3	6	ORG
# Ivory Coast	11	13	GPE
# thousands	17	18	CARDINAL
# the Security Council	4	7	ORG
# Kofi Annan	11	13	PERSON
# an additional 3,400	14	17	CARDINAL
# 475	19	20	CARDINAL
# African	26	27	NORP
# last October	3	5	DATE
# up to a year	9	13	DATE
# nearly 6,900	2	4	CARDINAL
# U.N.	4	5	ORG
# 4,000	7	8	CARDINAL
# French	8	9	NORP
# 700	1	2	CARDINAL
# Ivory Coast	13	15	GPE
# Annan	1	2	PERSON
# two	10	11	CARDINAL
# Abidjan	18	19	GPE
# 10	3	4	CARDINAL
# the United Nations	4	7	ORG
# Human Rights Commission	17	20	ORG
# weeks	21	22	DATE
# The New York Times	0	4	ORG
# Sunday	5	6	DATE
# U.N.	7	8	ORG
# this year	24	26	DATE
# later this month	6	9	DATE
# March	16	17	DATE
# Geneva	23	24	GPE
# Human Rights Commission	2	5	ORG
# Kofi Annan's	11	14	PERSON
# the United Nations	18	21	ORG
# Afghan	0	1	NORP
# two	3	4	CARDINAL
# Afghanistan	19	20	GPE
# at least 10	22	25	CARDINAL
# at least 13	29	32	CARDINAL
# Saturday	2	3	DATE
# Paktika province	7	9	GPE
# Taliban	1	2	ORG
# Reuters	0	1	ORG
# Taliban	5	6	ORG
# Afghanistan	2	3	GPE
# Afghan	4	5	GPE
# at least 15	9	12	CARDINAL
# Nangarhar province	14	16	GPE
#
# 	17	18	GPE
# Taliban	18	19	ORG
# one	10	11	CARDINAL
# Saturday	13	14	DATE
# Afghanistan	16	17	GPE
# U.S.	0	1	GPE
# George Bush	2	4	PERSON
# America	6	7	GPE
# Iraq	14	15	GPE
# Europe	22	23	LOC
# World War II	24	27	EVENT
# Bush	8	9	PERSON
# Iraq	22	23	GPE
# VOA White House	4	7	ORG
# Paula Wolfson	8	10	PERSON
# one	4	5	CARDINAL
# 16	6	7	CARDINAL
# Pakistani	8	9	NORP
# Tuesday	12	13	DATE
# Afghanistan	23	24	GPE
# Pakistani	0	1	NORP
# 10	18	19	CARDINAL
# August 9	5	7	DATE
# Taleban	18	19	GPE
# al-Qaida	20	23	PERSON
# Jandola	8	9	GPE
# 10-month	10	11	ORDINAL
# Pakistani	14	15	NORP
# North Waziristan	18	20	PERSON
# July	21	22	DATE
# Red Mosque	13	15	ORG
# Islamabad	16	17	GPE
# last month	17	19	DATE
# some 70	21	23	CARDINAL
# the Arab League	3	6	ORG
# Lebanon	7	8	GPE
# Syrian	11	12	NORP
# Emile Lahoud	14	16	PERSON
# Amr Moussa	0	2	PERSON
# Wednesday	3	4	DATE
# Lebanon	5	6	GPE
# Lahoud	10	11	PERSON
# November 2007	16	18	DATE
# Lebanon	0	1	GPE
# Syrian	5	6	NORP
# Moussa	0	1	PERSON
# Lebanon	3	4	GPE
# Tuesday	4	5	DATE
# second	7	8	ORDINAL
# a week	10	12	DATE
# Fuad Siniora	6	8	PERSON
# Damascus	15	16	GPE
# Thursday	16	17	DATE
# Hezbollah	0	1	ORG
# Syrian	5	6	NORP
# Cabinet	9	10	ORG
# November	11	12	DATE
# Hezbollah	2	3	ORG
# Beirut	9	10	GPE
# Siniora	14	15	PERSON
# Washington	1	2	GPE
# Wednesday	2	3	DATE
# Bush	5	6	PERSON
# Siniora	10	11	PERSON
# Syria	17	18	GPE
# Lebanon	23	24	GPE
# Iraqi	0	1	NORP
# Iraqi	18	19	NORP
# Ibrahim al-Jaafari's	21	26	PERSON
# Islamic Dawa Party	26	29	ORG
# Iraqi	9	10	NORP
# Ibrahim al-	12	14	PERSON
# at least one	19	22	CARDINAL
# Iraqi	0	1	NORP
# Friday	2	3	DATE
# at least one	9	12	CARDINAL
# Islamic	26	27	NORP
# Baghdad	30	31	GPE
# Mansour	32	33	GPE
# U.S.	2	3	GPE
# 12	10	11	CARDINAL
# three	17	18	CARDINAL
# Mosul	25	26	GPE
# GNAT	1	2	ORG
# Iraqi	0	1	NORP
# Monday	6	7	DATE
# Baghdad	12	13	GPE
# four	15	16	CARDINAL
# Karradah	12	13	GPE
# At least four	0	3	CARDINAL
# Sunday, three car	1	5	DATE
#
# Yassin Hassan Omar	11	14	PERSON
# today	7	8	DATE
# fourth	1	2	ORDINAL
# Hamdi Issac	5	7	PERSON
# Osman Hussein	11	13	PERSON
# Italian	16	17	NORP
# Britain	23	24	GPE
# British	2	3	NORP
# three	8	9	CARDINAL
# Muslim	9	10	NORP
# Britain	12	13	GPE
# One	0	1	CARDINAL
# Omar Bakri Mohammed	6	9	PERSON
# Muslims	21	22	NORP
# Britain	28	29	GPE
# Bush	2	3	PERSON
# second	6	7	ORDINAL
# Thursday	8	9	DATE
# one	19	20	CARDINAL
# American	23	24	NORP
# First	3	4	ORDINAL
# Laura Bush	5	7	PERSON
# nine	9	10	CARDINAL
# about 20 minutes	13	16	TIME
# a day	3	5	DATE
# Bush	9	10	PERSON
# Congress	16	17	ORG
# Cabinet	5	6	ORG
# Friday	5	6	DATE
# Washington	11	12	GPE
# National Cathedral	13	15	ORG
# The United Nations	0	3	ORG
# Sri Lanka	7	9	GPE
# Colombo	10	11	GPE
# Thursday	11	12	DATE
# Sri Lanka	19	21	GPE
# last month's	22	25	DATE
#
# 	27	28	PERSON
# Morjane	1	2	PERSON
# Tamils	24	25	ORG
# Some 80,000	0	2	CARDINAL
# Tamil Tiger	14	16	PERSON
# Serbian	0	1	NORP
# Albanian	12	13	NORP
# Kosovo	22	23	GPE
# Kosovo	0	1	GPE
# Fatmir Sejdiu	2	4	PERSON
# Thursday	4	5	DATE
# Agim Ceku	9	11	PERSON
# one day	17	19	DATE
# Bajram Kosumi	25	27	PERSON
# Kosumi	1	2	PERSON
# Ceku	0	1	PERSON
# the Kosovo Liberation Army	4	8	ORG
# Serb	9	10	NORP
# 1998	12	13	DATE
# 1999	14	15	DATE
# Belgrade	0	1	GPE
# Ceku of war	3	6	EVENT
# Serb	8	9	NORP
# Serbia	0	1	GPE
# Kosovo	2	3	GPE
# U.N	6	7	GPE
# Serbian	15	16	NORP
#
# 	18	19	GPE
# Serbia	6	7	GPE
# Pakistani	0	1	NORP
# Shi'ite Muslim	5	7	GPE
# Muslim	21	22	NORP
# Karachi	24	25	GPE
# last year	25	27	DATE
# Nafees Khan	8	10	PERSON
# one	4	5	CARDINAL
# six	6	7	CARDINAL
# Mufti Nizamuddin Shamzai	0	3	ORG
# the United States	16	19	GPE
# May 2004	24	26	DATE
# Islamic	31	32	NORP
# thousands	5	6	CARDINAL
# Karachi	10	11	GPE
# French	0	1	NORP
# Jacques Chirac	2	4	PERSON
# $2 billion	2	5	MONEY
# six	11	12	CARDINAL
# France	21	22	GPE
# French	7	8	NORP
# German	9	10	NORP
# Chirac	1	2	PERSON
# France	15	16	GPE
# Bangladesh	0	1	GPE
# 1,600	7	8	CARDINAL
# U.N.	12	13	ORG
# Sudan	16	17	GPE
# M. Morshed Khan	2	5	PERSON
# Dhaka	7	8	GPE
# Sunday	8	9	DATE
# Bangladeshi	11	12	NORP
# the United Nations	15	18	ORG
# Sudan	20	21	GPE
# about 10,000	28	30	CARDINAL
# January	10	11	DATE
# Khartoum	13	14	GPE
# People's Liberation Movement	18	22	ORG
# Bangladesh	0	1	GPE
# one	3	4	CARDINAL
# U.N.	11	12	ORG
# almost 8,000	2	4	CARDINAL
# 12	10	11	CARDINAL
# U.N.	11	12	ORG
# Iraq	2	3	GPE
# Mosul	12	13	GPE
# four	15	16	CARDINAL
# Friday	5	6	DATE
# Three	0	1	CARDINAL
# fourth	11	12	ORDINAL
# Iraqi	15	16	NORP
# U.S.	1	2	GPE
# Mosul	8	9	PERSON
# early last month	9	12	DATE
# U.S	15	16	GPE
# Fallujah	26	27	GPE
# Mosul	2	3	GPE
# recent weeks	6	8	DATE
# dozens	13	14	CARDINAL
# Iraqis	16	17	NORP
# Burma	4	5	GPE
# six	6	7	CARDINAL
# up to 28 years	13	17	DATE
# U.S. Embassy	25	27	ORG
# Rangoon	29	30	GPE
# earlier this year	30	33	DATE
# Aung Thein	3	5	PERSON
# Saturday	7	8	DATE
# six	9	10	CARDINAL
# Burma	9	10	GPE
# U.N.	0	1	GPE
# more than 150	6	9	CARDINAL
# August 19	24	26	DATE
# Burma	10	11	GPE
# recent weeks	12	14	DATE
# Pakokku	18	19	GPE
# Wednesday	19	20	DATE
# Thursday	1	2	DATE
# several hours	14	16	TIME
# Bolivian	1	2	NORP
# Eduardo Rodriguez	3	5	PERSON
# at least 28	16	19	CARDINAL
# Rodriguez	1	2	PERSON
# late Tuesday	4	6	DATE
# Marcelo Antezana	10	12	PERSON
# 28	17	18	CARDINAL
# Chinese	20	21	NORP
# the United States	25	28	GPE
# last year	31	33	DATE
# Rodriguez	1	2	PERSON
# the United States	15	18	GPE
# U.S. State Department	1	4	ORG
# last month	5	7	DATE
# U.S.-	13	14	GPE
# Bolivia	21	22	GPE
# Bolivia	2	3	GPE
# Christian	28	29	NORP
# Father	5	6	PERSON
# the Small Snakes	9	12	ORG
# Malawi	3	4	GPE
# thousands	14	15	CARDINAL
# Wilfred Lipita	7	9	PERSON
# South Africa	8	10	GPE
# Friday	1	2	DATE
# Jakarta	5	6	GPE
# 39-year-	11	12	DATE
# Indonesian	13	14	NORP
# the World Health Organization	3	7	ORG
# 10	12	13	CARDINAL
# Indonesia	18	19	GPE
# H5N1	24	25	FAC
# more than	8	10	PERCENT
# East Asia	13	15	LOC
# 2003	16	17	DATE
# U.S.	0	1	GPE
# National Guard	11	13	ORG
# the Gulf Coast	15	18	LOC
# National Guard	0	2	ORG
# New Orleans	5	7	GPE
# Thursday	7	8	DATE
# Defense	3	4	ORG
# Homeland Defense Paul McHale	5	9	EVENT
# Washington	14	15	GPE
# the National Guard	16	19	ORG
# the next three days	24	28	DATE
# New Orleans	34	36	GPE
# up to 30,000	8	11	CARDINAL
# National Guard	11	13	ORG
# the Gulf Coast	18	21	LOC
# Coast Guard Rear	0	3	ORG
# Joel Whitehead	4	6	PERSON
# nearly 3,000	2	4	CARDINAL
# Thursday	9	10	DATE
# Bush	1	2	PERSON
# Zalmay Khalilzad	5	7	PERSON
# U.S.	10	11	GPE
# Iraq	13	14	GPE
# Khalilzad	1	2	PERSON
# Afghan	4	5	NORP
# U.S.	11	12	GPE
# Afghanistan	14	15	GPE
# Khalilzad	5	6	PERSON
# John Negroponte	13	15	PERSON
# Baghdad	20	21	GPE
# Negroponte	5	6	PERSON
# the United States'	8	12	GPE
#
# 	18	19	PERSON
# 2003	1	2	DATE
# Bush	4	5	PERSON
# Khalilzad	7	8	PERSON
# Afghanistan	18	19	GPE
# one	5	6	CARDINAL
# Bush	14	15	PERSON
# Indian	0	1	NORP
# at least 513	3	6	CARDINAL
# Maharashtra	23	24	GPE
# Bombay	12	13	GPE
# Mumbai	17	18	ORG
# Tuesday	24	25	DATE
# Thursday	4	5	DATE
# thousands	13	14	CARDINAL
# Pope Benedict	0	2	PERSON
# hundreds	15	16	CARDINAL
# UK	6	7	GPE
# Jamaican	8	9	NORP
# 1962	11	12	DATE
# Jamaica	24	25	GPE
# Bahamas	4	5	PERSON
# 1965	8	9	DATE
# 1973	10	11	DATE
# Bahamian	1	2	NORP
# 1973	11	12	DATE
# 1982	6	7	DATE
# British	17	18	NORP
# Jamaican	0	1	NORP
# 91	3	4	CARDINAL
# American Airlines	12	14	ORG
# Kingston	24	25	GPE
# late Tuesday	25	27	DATE
# Boeing	1	2	ORG
# 737	2	3	PRODUCT
# 154	5	6	CARDINAL
# Norman Manley International Airport	14	18	FAC
# American Airlines	0	2	ORG
# two	5	6	CARDINAL
# Washington	4	5	GPE
# Reagan National Airport	6	9	FAC
# Miami	13	14	GPE
# Kingston	17	18	GPE
# American Airlines	3	5	ORG
# one	16	17	CARDINAL
# Iran	0	1	GPE
# U.N.	3	4	ORG
# Natanz	16	17	GPE
# Iran	0	1	GPE
# Nuclear Agency	2	4	ORG
# Saturday	5	6	DATE
# the International Atomic Energy Agency	7	12	ORG
# IAEA	13	14	ORG
# Iran	2	3	GPE
# Munich	18	19	GPE
# Germany	20	21	GPE
# German	0	1	NORP
# Angela Merkel	2	4	PERSON
# Tehran	9	10	GPE
#
# 	16	17	PERSON
# Iran	3	4	GPE
# Germany	0	1	GPE
# European Union	4	6	ORG
# Russian	0	1	NORP
# Vladimir Putin	2	4	PERSON
# Iran	10	11	GPE
# International Atomic Energy Agency	19	23	ORG
# Mohamed ElBaradei	24	26	PERSON
# U.N.	7	8	ORG
# Iran	10	11	GPE
#
# 	18	19	PERSON
# Iran	0	1	GPE
# Ali Larijani	6	8	PERSON
# Saturday	12	13	DATE
# Friday	19	20	DATE
# IAEA	1	2	ORG
# nearly half	3	5	CARDINAL
# 55	7	8	CARDINAL
# Iran	12	13	GPE
# Friday	13	14	DATE
# U.N.	17	18	ORG
# December	21	22	DATE
# Tehran	23	24	GPE
# U.S.	1	2	GPE
# Western	4	5	NORP
# Iran	7	8	GPE
# Iran	17	18	GPE
# South Korea	0	2	GPE
# Pyongyang	3	4	GPE
# North Korean	1	3	NORP
# Wednesday	5	6	DATE
# 8,000	9	10	CARDINAL
# South Korean	0	2	NORP
# Rhee Bong-jo	5	9	PERSON
# Seoul	12	13	GPE
# Thursday	13	14	DATE
# Pyongyang	15	16	GPE
#
# 	35	36	GPE
# North Korea	2	4	GPE
# six	8	9	CARDINAL
# almost a year	3	6	DATE
# U.S.	1	2	GPE
# North Korean	5	7	NORP
# Christopher Hill	10	12	PERSON
# Seoul	18	19	GPE
# Friday	19	20	DATE
# South Korean	23	25	NORP
# Taiwan	3	4	GPE
# Monday	9	10	DATE
# Tokyo	12	13	GPE
# Japan	22	23	GPE
# Su Chin-chiang	0	4	PERSON
# the Taiwan Solidarity Union	7	11	ORG
# Yasukuni Shrine	20	22	PERSON
# 14	24	25	CARDINAL
# Japanese	26	27	NORP
# thousands	38	39	CARDINAL
# Taiwan	40	41	GPE
# Annual	0	1	DATE
# Japanese	6	7	NORP
# Junichiro Koizumi	9	11	PERSON
# China	19	20	GPE
# South Korea	21	23	GPE
# Taiwan	0	1	GPE
# Japan	4	5	GPE
# 1895	6	7	DATE
# 1945	8	9	DATE
# Su	1	2	PERSON
# Taiwan	15	16	GPE
# Egyptian	0	1	NORP
# Hosni Mubarak	6	8	PERSON
# earlier this month	17	20	DATE
# Mubarak	26	27	PERSON
# Egyptian	1	2	NORP
# last month	4	6	DATE
# Ibrahim Eissa	8	10	PERSON
# two months	12	14	DATE
# Al-Dustour	11	14	WORK_OF_ART
# daily	15	16	DATE
# last year	6	8	DATE
# Mubarak	10	11	PERSON
# 80 years old	13	16	DATE
#
# 	22	23	PERSON
# to six months	6	9	DATE
# Eissa	0	1	ORG
# the past year	11	14	DATE
# Egyptian	20	21	NORP
# Guyanese	1	2	NORP
# recent years	8	10	DATE
# six	9	10	CARDINAL
# nearly 60% of	27	30	PERCENT
# Guyana	0	1	GPE
# the Caricom Single Market	4	8	ORG
# CSME	11	12	ORG
# January 2006	14	16	DATE
# 2005	4	5	DATE
# March 2007	1	3	DATE
# Inter-American Development Bank	5	10	ORG
# Guyana	11	12	GPE
# Guyana	17	18	GPE
# nearly $470 million	19	23	MONEY
# nearly 48% of	27	30	PERCENT
# Highly Indebted Poor Country	36	40	ORG
# 183% in	55	57	PERCENT
# 2006	57	58	DATE
# 120% in	59	61	PERCENT
# 2007	61	62	DATE
# Guyana	0	1	GPE
# the 1970s and 1980s	20	24	DATE
# 2009-10	3	6	DATE
# Beirut	6	7	GPE
# one	10	11	CARDINAL
# About 10	0	2	CARDINAL
# Lebanon	2	3	GPE
# Rafik al Hariri	17	20	PERSON
# 60-year-old	1	4	DATE
# last October	7	9	DATE
# Beirut	13	14	GPE
# Beirut	3	4	GPE
# St. George Hotel	6	9	ORG
# The U.S. Senate	0	3	ORG
# Burmese	9	10	NORP
# Earlier this month	0	3	DATE
# Burma	6	7	GPE
# Karen	14	15	PERSON
# more than 10,000	2	5	CARDINAL
# Senate	1	2	ORG
# Thursday	5	6	DATE
# the U.N. Security Council	8	12	ORG
# Burmese	24	25	NORP
# Aung San	27	29	PERSON
# Kyi	30	31	PERSON
# Burma	38	39	GPE

# %% [markdown]
# Read the [section about named entities](https://spacy.io/usage/linguistic-features#section-named-entities) from spaCy&rsquo;s documentation to get some background on this. (Please note that we are using version&nbsp;1 of the spaCy library, which means that there may be slight differences in the usage. At the time of writing, the current version&nbsp;2 is not yet stable and fast enough for this lab.)

# %% [markdown]
# ## Problem 1: Extract relevant pairs

# %% [markdown]
# The first problem that you will have to solve is to identify pairs of entities that are in the &lsquo;is-leader-of&rsquo; relation, as in the example above. There are many ways to do this, but for this lab it suffices to implement the strategy outlined in the section on [Relation Extraction](http://www.nltk.org/book/ch07.html#relation-extraction) in the book by Bird, Klein, and Loper (2009):
#
# * look for all triples of the form $(X, \alpha, Y)$ where $X$ and $Y$ are named entities of type *person* and $\alpha$ is the intervening text
# * write a regular expression to match just those instances of $\alpha$ that express the &lsquo;is-leader-of&rsquo; relation
#
# You can restrict your attention to adjacent pairs of entities &ndash; that is, cases where $X$ precedes $Y$ and $\alpha$ does not contain other named entities.
#
# Write a function `extract` that takes an analysed sentence (represented as a spaCy [`Doc`](https://spacy.io/api/doc) object) and yields pairs $(X, Y)$ of strings representing entity mentions predicted to be in the &lsquo;is-leader-of&rsquo; relation.

# %%
import nltk, re
def extract(doc):
    """Extract relevant relation instances from the specified document.
    
    Args:
        doc: The sentence as analysed by spaCy.
    Yields:
        Pairs of strings representing the extracted relation instances.
    """
    # TODO: Replace the following line with your own code
    leader = re.compile(r'.*(lead|command|direct|govern|head|manage|preside|supervis|chief|patron).*')
    person = None
    org= None
    ReturningString = []
    for ent in doc.ents:
        if ent.label_=="PERSON":
            person = ent
        else:
            if ent.label_ == "ORG" and person != None:
                org = ent
                intervening_words = doc.text.split(" ")[person.end:org.start]
                intervening_sentence = " ".join(intervening_words)
                if re.search(leader, intervening_sentence):
                    ReturningString.append((person, org))
                    person = None
                    org = None
    return(ReturningString)

# %% [markdown]
# The following cell shows how your function is supposed to be used. The code prints out the extracted pairs for the first 1,000&nbsp;sentences in the data. It additionally numbers each pair with the identifier of the sentence (line number in the data file) which it was extracted from. Note that the sentence (line) numbering starts at index&nbsp;0.

# %%
for i, doc in enumerate(nlp.pipe(data)):
    if i == 1000:
        break
    for person, org in extract(doc):
        print("{}\t{}\t{}".format(i, person, org))
# Out:
# 207	Rugova	European Union
# 283	Michael Green	the U.S. National Security Council
# 351	Jendayi Frazer	Sudan Liberation Army
# 362	Dudley	TNK-BP
# 391	Mahmoud Abbas	Fatah
# 512	Kyi	the National League for Democracy
# 638	Hassan	CARE
# 802	Asif Ali Zardari	the Pakistan People's Party

# %% [markdown]
# Once you feel confident that your `extract` function does what it is supposed to do, execute the following cell to extract the entities from the full data set. Note that this will probably take a few minutes.

# %%
extracted = set()
for i, doc in enumerate(nlp.pipe(data)):
    if  i == 62009:
        break
    for words in extract(doc):
        extracted.add((i, person, org))

# %% [markdown]
# After executing the above cell, all extracted id-string-string triples are in the set `extracted`. The code in the next cell will print the first 10&nbsp;triples in this set.

# %%
for i, words in sorted(extracted)[:10]:
    print("{}\t{}\t{}".format(i, person, org))
# Out:
#   File "<ipython-input-11-3f7dffc638b7>", line 2
#     print("{}\t{}\t{}".format(i, person, org))
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# ## Problem 2: Evaluate your system

# %% [markdown]
# You now have an extractor, but how good is it? To help you answer this question, we provide you with a &lsquo;gold standard&rsquo; of entity pairs that your system should be able to extract. The following code loads them (again augmented with the relevant sentence id) from the file `gold.txt` and adds them to the set `gold`:

# %%
gold_file = "C:/Users/Carles/Desktop/MasterStatistics-MachineLearning/Master_subjects/Text_Mining/Labs/Lab2/gold.txt"

gold = set()
with open(gold_file) as fp:
    for line in fp:
        columns = line.rstrip().split('\t')
        gold.add((int(columns[0]), columns[1], columns[2]))

# %% [markdown]
# The following code prints the 10&nbsp;first pairs from the gold standard:

# %%
for i, person, org in sorted(gold)[:10]:
    print("{}\t{}\t{}".format(i, person, org))

# %% [markdown]
# Your task now is to write code that computes the precision, recall, and F1 measure of your extractor relative to the gold standard.

# %%
def evaluate(reference, predicted):
    """Print out the precision, recall, and F1 for the id-entity-entity
    triples in the set `predicted`, given the triples in the reference set.
    
    Args:
        reference: The reference set of triples.
        predicted: The set of predicted triples.
    Returns:
        Nothing, but prints out precision, recall, and F1.
        Precision: Nº words predicted as NN which are NN in gold standard /sum(total of NN of predicted)
        Recall:  Nº words predicted as NN which are NN in gold standard /sum(total of NN of Gold standard)
        F1 for the id-entity-entity: 2*Precision*Recall/(Precision + Recall)
    """
    # TODO: Replace the next line with your own code
    tm2.evaluate(reference, predicted)

# %% [markdown]
# The next cell shows how your function is intended to be used, as well as the suggested output format.

# %%
evaluate(gold, extracted)

# %% [markdown]
# ## Problem 3: Entity resolution

# %% [markdown]
# Looking at the results of your quantitative evaluation, you will realise that your extractor (probably) does a rather poor job in matching the gold standard. One reason for this is that the NLP preprocessing is not perfect (spaCy was not trained on the annotations in the Groningen Meaning Bank), and that the approach of using regular expressions for relation extraction is rather naive.
#
# Another reason however is that the current version of your system does not include a component for *entity resolution*. To give an example, your system does not realise that the strings `David Petraeus` and `General David Petraeus` refer to the same entity.
#
# While writing an entity resolver is beyond the scope of this assignment, we ask you to *simulate* such a resolver. More specifically, you should implement a function `normalise` that takes an entity mention (a string) as its input and rewrites it to the form used in the gold standard. While in some sense this is &lsquo;cheating&rsquo;, it allows you to assess the performance of a more realistic system.
#
# The following cell contains skeleton code for the `normalise` function.

# %%
def normalise(text):
    if text == "David Petraeus":
        return "General David Petraeus"
    return text

# %% [markdown]
# The next cell shows how `normalise` is intended to be used. Each triple in the set `extracted` is transformed by feeding the two entity mentions into the `normalise` function. The normalised triples are then added to a new set `extracted_normalised`.

# %%
extracted_normalised = set()
for triple in extracted:
    extracted_normalised.add((triple[0], normalise(triple[1]), normalise(triple[2])))

# %% [markdown]
# To pass the assignment, you should add enough normalisation rules to `normalise` to achieve a recall of at least 50%.

# %%
evaluate(gold, extracted_normalised)

# %% [markdown]
# ## Problem 4: Limitations of the gold standard

# %% [markdown]
# Each entity pair in the gold standard has been manually checked for correctness. However, there is no guarantee that the gold standard contains all relevant pairs &ndash; there are in fact many pairs that are missing from the gold standard. Your last task in this assignment is to find at least 5&nbsp;entity pairs in the data that are valid instances of the &lsquo;is-leader-of&rsquo; relation but are not contained in the gold standard.
#
# You can solve this task either by writing code or by manual work (inspecting the data file), or mix the two strategies. In any case, you should enter your pairs in the textbox below. Use the triple format shown above where for each pair you also specify the sentence id (line number in the data file) from which the instance was extracted.

# %% [raw]
# sentence_id    entity 1    entity 2

# %% [markdown]
# Finally we ask you to reflect on the limitations of the evaluation that you carried out in this lab and discuss the question: *How should systems for information extraction really be evaluated?*. Here are some starting points for your discussion.
#
# * How could one create a better gold standard for this task?
# * What do precision, recall, and F1 actually measure in this context?
# * What measures would be more suitable to evaluate this task?
# * What other ways of evaluating systems for information extraction can you think of?
#
# Submit your discussion as a short text (ca. 250&nbsp;words). When presenting your arguments, link back to your own results and experience from this lab, and to concepts you have learned in the lectures or in other parts of the course.

# %% [markdown]
# *TODO: Enter your discussion here*

# %% [markdown]
# This is the end of the assignment.
